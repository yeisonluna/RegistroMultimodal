# %% [markdown]
# <a href="https://colab.research.google.com/github/yeisonluna/RegistroMultimodal/blob/main/Registro_Multimodal_CCORR_Multiescala_v_final_Yeison_Luna_TG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGISTRO MULTIMODAL DE IMÁGENES CON CORRELACION CRUZADA - BÚSQUEDA MULTIESCALA**
#
#
#
# ---

# %% [markdown]
# Importación de Bibliotecas

# %%
import numpy as np  #paquete de arreglos
import matplotlib as pyplot 
import matplotlib.pyplot as plt  # paquete de gráficos
import cv2 
from google.colab.patches import cv2_imshow # para imprimir imágenes

# %% [markdown]
# Se importan las imágenes, guardadas en un drive de google.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importación de Imágenes

# %%
plt.style.use('ggplot')
#imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/img358.tif")
#imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Paciente_1010244758_Presion-Promedio_2a_Pre_Procesada_2.TIFF")
imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Podoscopio_preprocesada_total.JPG")
imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift.TIFF")

# %% [markdown]
# # Funciones del algoritmo

# %% [markdown]
# Funcion multiescala

# %%
def scale_img_1(im1, im2):
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 
    escala_max = 1

# ----------------------------------- Ciclo 1 -------------------------------- #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = escala_max/n_int
        b1 = 0.2
        f = float(m1*i+b1)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,f)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]
            
        NCC_1.append(ncc)
        print("Correlacion cruzada en escala: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    scale = np.where(NCC_1==max(NCC_1))
    escala = scale[0]
    
    print("La primera escala es: ",m1*escala+b1)

    funcion_final = float(m1*escala)
    

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala 

def scale_img_2(im1,im2,escala):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]
    escala_max = 1

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
        

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*escala_max/(n_int**2)
        b2 = 0.2 + escala_max*(escala-1)/n_int 
        g = float(m2*j+b2)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,g)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en escala: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    scale_2 = np.where(NCC_2==max(NCC_2))
    escala_2 = scale_2[0]
    
    print("La segunda escala es: ",m2*escala_2+b2)

    funcion_final = float(m2*escala_2+b2)    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala_2
    

def scale_img_3(im1,im2,escala,escala_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    escala_max = 1


    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)


        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 4*escala_max/(n_int**3)
        b3 = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
        h = float(m3*k+b3)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,h)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en escala: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    scale_3 = np.where(NCC_3==max(NCC_3))
    escala_3 = scale_3[0]
    
    print("La tercera escala es: ",m3*escala_3+b3)
    
    m_final = 4*escala_max/(n_int**3)
    b_final = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
    funcion_final = float(m_final*escala_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funciones de traslacion

# %%
def shift_img_x_1(im1, im2):
    
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    
    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*cols/n_int   
        b1 = 0-cols
        f = (m1*i + b1)
            
        shift_matrix_x_axis = np.float32([[1,0,f],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en traslacion x: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_x = np.where(NCC_1==max(NCC_1))
    traslacion_x = shift_x[0]
    
    print("La primera traslacion es: ",m1*traslacion_x+b1)

    funcion_final = (m1*traslacion_x+b1) 
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x

def shift_img_x_2(im1, im2, traslacion_x):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]

    for j in range (n_int+1): 
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2 

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*cols)/(n_int**2)
        b2 = (2*cols*(traslacion_x-1))/n_int - (cols)
        g = (m2*j+b2)
                
        shift_matrix_x_axis = np.float32([[1,0,g],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en traslacion x: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_x_2 = np.where(NCC_2==max(NCC_2))
    traslacion_x_2 = shift_x_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_x_2+b2)

    funcion_final = (m2*traslacion_x_2+b2)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x_2

def shift_img_x_3(im1,im2,traslacion_x,traslacion_x_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*cols)/(n_int**3)
        b3 = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
        h = (m3*k+b3)
                
        shift_matrix_x_axis = np.float32([[1,0,h],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en traslacion x: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_x_3 = np.where(NCC_3==max(NCC_3))
    traslacion_x_3 = shift_x_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_x_3+b3)
    

    m_final = 2*(4*cols)/(n_int**3)
    b_final = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
    funcion_final = (m_final*traslacion_x_3+b_final)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de traslación en y

# %%
def shift_img_y_1(im1, im2):   
   
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 

    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*rows/n_int   
        b1 = 0-rows
        f = (m1*i + b1)
            
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,f]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en traslacion y: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_y = np.where(NCC_1==max(NCC_1))
    traslacion_y = shift_y[0]
    
    print("La primera traslacion es: ",m1*traslacion_y+b1)

    funcion_final = (m1*traslacion_y + b1)    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y


def shift_img_y_2(im1,im2,traslacion_y):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]


    for j in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*rows)/(n_int**2)
        b2 = (2*rows*(traslacion_y-1))/n_int - (rows)
        g = (m2*j+b2)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,g]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            

            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en traslacion y: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_y_2 = np.where(NCC_2==max(NCC_2))
    traslacion_y_2 = shift_y_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_y_2+b2)

    funcion_final = (m2*traslacion_y_2+b2)     

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y_2

def shift_img_y_3(im1,im2,traslacion_y,traslacion_y_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*rows)/(n_int**3)
        b3 = 2*(2*rows)*(traslacion_y_2-1)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
        h = (m3*k+b3)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,h]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en traslacion y: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_y_3 = np.where(NCC_3==max(NCC_3))
    traslacion_y_3 = shift_y_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_y_3+b3)
    

    m_final = 2*(4*rows)/(n_int**3)
    b_final = 2*(2*rows)*(traslacion_y_2)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
    funcion_final = (m_final*traslacion_y_3+b_final)
    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de rotación

# %%
def rotation_matrix_1(im1, im2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1 = []
    angulo_max = 3

# ----------------------------------- Ciclo 1 ------------------------------------ #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*angulo_max/n_int
        b1 = 0-angulo_max
        f = float(m1*i+b1)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),f,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en rotacion: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    angle = np.where(NCC_1==max(NCC_1))
    angulo = angle[0]
    
    print("La primera rotación es: ",m1*angulo+b1)

    funcion_final = float(m1*angulo+b1)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo

def rotation_matrix_2(im1, im2, angulo):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2 = []
    angulo_max = 3

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*2*angulo_max/(n_int**2)
        b2 = 2*angulo_max*(angulo-1)/n_int - angulo_max
        g = float(m2*j+b2)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),g,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en rotación: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    angle_2 = np.where(NCC_2==max(NCC_2))
    angulo_2 = angle_2[0]
    
    print("La segunda rotación es: ",m2*angulo_2+b2)

    funcion_final = float(m2*angulo_2+b2)
     

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo_2

def rotation_matrix_3(im1, im2, angulo, angulo_2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    angulo_max = 3

    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*4*angulo_max/(n_int**3)
        b3 = 2*angulo_max*(angulo-1)/n_int + 2*2*angulo_max*(angulo_2-1)/(n_int**2) - angulo_max
        h = float(m3*k+b3)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),h,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en rotación: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    angle_3 = np.where(NCC_3==max(NCC_3))
    angulo_3 = angle_3[0]
    
    print("La tercera rotación es: ",m3*angulo_3+b3)
    
    m_final = 2*4*angulo_max/(n_int**3)
    b_final = angulo_max*(angulo-1)/n_int + 2*angulo_max*(angulo_2-1)/(n_int**2)
    funcion_final = float(m_final*angulo_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# # Resultados

# %%
#----------------------------------------------------------------------------------------#
#Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s1, s1 = scale_img_1(imagen1, imagen2)

plt.figure(0)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s1,'gray'),plt.title('S1')

imagen2_sx1, x1 = shift_img_x_1(imagen1, imagen2_s1)

plt.figure(1)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx1,'gray'),plt.title('S1, X1')

imagen2_sxy1, y1 = shift_img_y_1(imagen1, imagen2_sx1)

plt.figure(2)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy1,'gray'),plt.title('S1, X1, Y1')

imagen2_sxyr1, r1 = rotation_matrix_1(imagen1, imagen2_sxy1)

plt.figure(3)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr1,'gray'),plt.title('S1, X1, Y1, R1')

print("\n")

#----------------------------------------------------------------------------------------#
#Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
print("Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s2, s2 = scale_img_2(imagen1, imagen2, s1)

plt.figure(4)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s2,'gray'),plt.title('S2')

imagen2_sx2, x2 = shift_img_x_2(imagen1, imagen2_s2, x1)

plt.figure(5)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx2,'gray'),plt.title('S2, X2')

imagen2_sxy2, y2 = shift_img_y_2(imagen1, imagen2_sx2, y1)

plt.figure(6)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy2,'gray'),plt.title('S2, X2, Y2')


imagen2_sxyr2, r2 = rotation_matrix_2(imagen1, imagen2_sxy2, r1)

plt.figure(7)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr2,'gray'),plt.title('S2, X2, Y2, R2')

print("\n")

#----------------------------------------------------------------------------------------#
#Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s3, s3 = scale_img_3(imagen1, imagen2, s1, s2)

plt.figure(8)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s3,'gray'),plt.title('S3')

imagen2_sx3, x3 = shift_img_x_3(imagen1, imagen2_s3, x1, x2)

plt.figure(9)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx3,'gray'),plt.title('S3, X3')

imagen2_sxy3, y3 = shift_img_y_3(imagen1, imagen2_sx3, y1, y2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy3,'gray'),plt.title('S3, X3, Y3')


imagen2_sxyr3, r3 = rotation_matrix_3(imagen1, imagen2_sxy3, r1, r2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('S3, X3, Y3, R3')



#----------------------------------------------------------------------------------------#
# Mostrando el resultado final #


plt.figure(11)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('Original')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('Registro Completo')
# Out:
# Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  0.2   [3832809.5]
# Correlacion cruzada en escala:  0.25   [6575066.5]
# Correlacion cruzada en escala:  0.30000000000000004   [10202950.]
# Correlacion cruzada en escala:  0.35000000000000003   [14750661.]
# Correlacion cruzada en escala:  0.4   [20339906.]
# Correlacion cruzada en escala:  0.45   [26952440.]
# Correlacion cruzada en escala:  0.5   [34539684.]
# Correlacion cruzada en escala:  0.55   [42915260.]
# Correlacion cruzada en escala:  0.6000000000000001   [52211724.]
# Correlacion cruzada en escala:  0.65   [62271490.]
# Correlacion cruzada en escala:  0.7   [72797000.]
# Correlacion cruzada en escala:  0.75   [83569510.]
# Correlacion cruzada en escala:  0.8   [94915120.]
# Correlacion cruzada en escala:  0.8500000000000001   [1.0745716e+08]
# Correlacion cruzada en escala:  0.9000000000000001   [1.2085611e+08]
# Correlacion cruzada en escala:  0.95   [1.3413199e+08]
# Correlacion cruzada en escala:  1.0   [1.4572112e+08]
# Correlacion cruzada en escala:  1.05   [1.5400859e+08]
# Correlacion cruzada en escala:  1.1   [1.5898517e+08]
# Correlacion cruzada en escala:  1.1500000000000001   [1.6218453e+08]
# Correlacion cruzada en escala:  1.2   [1.6542237e+08]
# La primera escala es:  [1.2]
# Correlacion cruzada en traslacion x:  -455.0   [0.]
# Correlacion cruzada en traslacion x:  -409.5   [0.]
# Correlacion cruzada en traslacion x:  -364.0   [0.]
# Correlacion cruzada en traslacion x:  -318.5   [0.]
# Correlacion cruzada en traslacion x:  -273.0   [326766.94]
# Correlacion cruzada en traslacion x:  -227.5   [16554080.]
# Correlacion cruzada en traslacion x:  -182.0   [34768070.]
# Correlacion cruzada en traslacion x:  -136.5   [37432964.]
# Correlacion cruzada en traslacion x:  -91.0   [38315560.]
# Correlacion cruzada en traslacion x:  -45.5   [55526628.]
# Correlacion cruzada en traslacion x:  0.0   [1.6542237e+08]
# Correlacion cruzada en traslacion x:  45.5   [69859590.]
# Correlacion cruzada en traslacion x:  91.0   [36489004.]
# Correlacion cruzada en traslacion x:  136.5   [40438108.]
# Correlacion cruzada en traslacion x:  182.0   [39881490.]
# Correlacion cruzada en traslacion x:  227.5   [21214992.]
# Correlacion cruzada en traslacion x:  273.0   [2153108.5]
# Correlacion cruzada en traslacion x:  318.5   [0.]
# Correlacion cruzada en traslacion x:  364.0   [0.]
# Correlacion cruzada en traslacion x:  409.5   [0.]
# Correlacion cruzada en traslacion x:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada en traslacion y:  -455.0   [0.]
# Correlacion cruzada en traslacion y:  -409.5   [0.]
# Correlacion cruzada en traslacion y:  -364.0   [0.]
# Correlacion cruzada en traslacion y:  -318.5   [2785630.5]
# Correlacion cruzada en traslacion y:  -273.0   [14812291.]
# Correlacion cruzada en traslacion y:  -227.5   [19258928.]
# Correlacion cruzada en traslacion y:  -182.0   [33123542.]
# Correlacion cruzada en traslacion y:  -136.5   [60858900.]
# Correlacion cruzada en traslacion y:  -91.0   [73639180.]
# Correlacion cruzada en traslacion y:  -45.5   [1.1667937e+08]
# Correlacion cruzada en traslacion y:  0.0   [1.6542237e+08]
# Correlacion cruzada en traslacion y:  45.5   [97052370.]
# Correlacion cruzada en traslacion y:  91.0   [68135290.]
# Correlacion cruzada en traslacion y:  136.5   [44542270.]
# Correlacion cruzada en traslacion y:  182.0   [18898616.]
# Correlacion cruzada en traslacion y:  227.5   [14494332.]
# Correlacion cruzada en traslacion y:  273.0   [6721427.5]
# Correlacion cruzada en traslacion y:  318.5   [1107371.]
# Correlacion cruzada en traslacion y:  364.0   [0.]
# Correlacion cruzada en traslacion y:  409.5   [0.]
# Correlacion cruzada en traslacion y:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada en rotacion:  -3.0   [1.6391336e+08]
# Correlacion cruzada en rotacion:  -2.7   [1.6413586e+08]
# Correlacion cruzada en rotacion:  -2.4   [1.6435104e+08]
# Correlacion cruzada en rotacion:  -2.1   [1.6453566e+08]
# Correlacion cruzada en rotacion:  -1.8   [1.6472272e+08]
# Correlacion cruzada en rotacion:  -1.5   [1.6486115e+08]
# Correlacion cruzada en rotacion:  -1.2000000000000002   [1.6501138e+08]
# Correlacion cruzada en rotacion:  -0.8999999999999999   [1.6515794e+08]
# Correlacion cruzada en rotacion:  -0.6000000000000001   [1.6524157e+08]
# Correlacion cruzada en rotacion:  -0.30000000000000027   [1.6535738e+08]
# Correlacion cruzada en rotacion:  0.0   [1.6542237e+08]
# Correlacion cruzada en rotacion:  0.2999999999999998   [1.6547006e+08]
# Correlacion cruzada en rotacion:  0.5999999999999996   [1.654969e+08]
# Correlacion cruzada en rotacion:  0.8999999999999999   [1.6554947e+08]
# Correlacion cruzada en rotacion:  1.2000000000000002   [1.655273e+08]
# Correlacion cruzada en rotacion:  1.5   [1.6551376e+08]
# Correlacion cruzada en rotacion:  1.7999999999999998   [1.6543461e+08]
# Correlacion cruzada en rotacion:  2.0999999999999996   [1.6540952e+08]
# Correlacion cruzada en rotacion:  2.3999999999999995   [1.6532526e+08]
# Correlacion cruzada en rotacion:  2.7   [1.6524491e+08]
# Correlacion cruzada en rotacion:  3.0   [1.6512506e+08]
# La primera rotación es:  [0.9]
#
#
# Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  1.15   [1.6218453e+08]
# Correlacion cruzada en escala:  1.1549999999999998   [1.6246794e+08]
# Correlacion cruzada en escala:  1.16   [1.6280949e+08]
# Correlacion cruzada en escala:  1.1649999999999998   [1.6312758e+08]
# Correlacion cruzada en escala:  1.17   [1.634298e+08]
# Correlacion cruzada en escala:  1.1749999999999998   [1.6374448e+08]
# Correlacion cruzada en escala:  1.18   [1.6401373e+08]
# Correlacion cruzada en escala:  1.1849999999999998   [1.6439043e+08]
# Correlacion cruzada en escala:  1.19   [1.6472328e+08]
# Correlacion cruzada en escala:  1.1949999999999998   [1.6506549e+08]
# Correlacion cruzada en escala:  1.2   [1.6542237e+08]
# Correlacion cruzada en escala:  1.2049999999999998   [1.6573034e+08]
# Correlacion cruzada en escala:  1.21   [1.6609182e+08]
# Correlacion cruzada en escala:  1.2149999999999999   [1.6650715e+08]
# Correlacion cruzada en escala:  1.22   [1.6686163e+08]
# Correlacion cruzada en escala:  1.2249999999999999   [1.6720987e+08]
# Correlacion cruzada en escala:  1.23   [1.6756269e+08]
# Correlacion cruzada en escala:  1.2349999999999999   [1.67967e+08]
# Correlacion cruzada en escala:  1.24   [1.6835056e+08]
# Correlacion cruzada en escala:  1.2449999999999999   [1.687391e+08]
# Correlacion cruzada en escala:  1.25   [1.6915912e+08]
# La segunda escala es:  [1.25]
# Correlacion cruzada en traslacion x:  [-45.5]   [83210460.]
# Correlacion cruzada en traslacion x:  [-40.95]   [90344184.]
# Correlacion cruzada en traslacion x:  [-36.4]   [99208200.]
# Correlacion cruzada en traslacion x:  [-31.85]   [1.0916877e+08]
# Correlacion cruzada en traslacion x:  [-27.3]   [1.1992874e+08]
# Correlacion cruzada en traslacion x:  [-22.75]   [1.3181684e+08]
# Correlacion cruzada en traslacion x:  [-18.2]   [1.4364691e+08]
# Correlacion cruzada en traslacion x:  [-13.65]   [1.5558453e+08]
# Correlacion cruzada en traslacion x:  [-9.1]   [1.6743784e+08]
# Correlacion cruzada en traslacion x:  [-4.55]   [1.77236e+08]
# Correlacion cruzada en traslacion x:  [0.]   [1.8566062e+08]
# Correlacion cruzada en traslacion x:  [4.55]   [1.9351563e+08]
# Correlacion cruzada en traslacion x:  [9.1]   [1.9928829e+08]
# Correlacion cruzada en traslacion x:  [13.65]   [2.0176725e+08]
# Correlacion cruzada en traslacion x:  [18.2]   [2.0006821e+08]
# Correlacion cruzada en traslacion x:  [22.75]   [1.9522338e+08]
# Correlacion cruzada en traslacion x:  [27.3]   [1.8781093e+08]
# Correlacion cruzada en traslacion x:  [31.85]   [1.7834848e+08]
# Correlacion cruzada en traslacion x:  [36.4]   [1.6668816e+08]
# Correlacion cruzada en traslacion x:  [40.95]   [1.5370424e+08]
# Correlacion cruzada en traslacion x:  [45.5]   [1.4039946e+08]
# La segunda traslacion es:  [13.65]
# Correlacion cruzada en traslacion y:  [-45.5]   [1.6026275e+08]
# Correlacion cruzada en traslacion y:  [-40.95]   [1.6737587e+08]
# Correlacion cruzada en traslacion y:  [-36.4]   [1.7461528e+08]
# Correlacion cruzada en traslacion y:  [-31.85]   [1.810802e+08]
# Correlacion cruzada en traslacion y:  [-27.3]   [1.8708283e+08]
# Correlacion cruzada en traslacion y:  [-22.75]   [1.9256046e+08]
# Correlacion cruzada en traslacion y:  [-18.2]   [1.9706056e+08]
# Correlacion cruzada en traslacion y:  [-13.65]   [2.0044605e+08]
# Correlacion cruzada en traslacion y:  [-9.1]   [2.0251342e+08]
# Correlacion cruzada en traslacion y:  [-4.55]   [2.0303376e+08]
# Correlacion cruzada en traslacion y:  [0.]   [2.0176725e+08]
# Correlacion cruzada en traslacion y:  [4.55]   [1.9829957e+08]
# Correlacion cruzada en traslacion y:  [9.1]   [1.9348538e+08]
# Correlacion cruzada en traslacion y:  [13.65]   [1.8859426e+08]
# Correlacion cruzada en traslacion y:  [18.2]   [1.8411211e+08]
# Correlacion cruzada en traslacion y:  [22.75]   [1.801993e+08]
# Correlacion cruzada en traslacion y:  [27.3]   [1.7533408e+08]
# Correlacion cruzada en traslacion y:  [31.85]   [1.7077534e+08]
# Correlacion cruzada en traslacion y:  [36.4]   [1.6623482e+08]
# Correlacion cruzada en traslacion y:  [40.95]   [1.6143792e+08]
# Correlacion cruzada en traslacion y:  [45.5]   [1.5682128e+08]
# La segunda traslacion es:  [-4.55]
# Correlacion cruzada en rotación:  0.6000000000000001   [2.0262672e+08]
# Correlacion cruzada en rotación:  0.6300000000000001   [2.0262398e+08]
# Correlacion cruzada en rotación:  0.6600000000000001   [2.0259683e+08]
# Correlacion cruzada en rotación:  0.6900000000000001   [2.0257754e+08]
# Correlacion cruzada en rotación:  0.7200000000000001   [2.0255066e+08]
# Correlacion cruzada en rotación:  0.7500000000000001   [2.0253227e+08]
# Correlacion cruzada en rotación:  0.78   [2.0251523e+08]
# Correlacion cruzada en rotación:  0.81   [2.025055e+08]
# Correlacion cruzada en rotación:  0.8400000000000001   [2.0248032e+08]
# Correlacion cruzada en rotación:  0.8700000000000001   [2.0245371e+08]
# Correlacion cruzada en rotación:  0.9000000000000001   [2.0244875e+08]
# Correlacion cruzada en rotación:  0.93   [2.023976e+08]
# Correlacion cruzada en rotación:  0.9600000000000001   [2.0236914e+08]
# Correlacion cruzada en rotación:  0.9900000000000001   [2.023506e+08]
# Correlacion cruzada en rotación:  1.02   [2.0233354e+08]
# Correlacion cruzada en rotación:  1.05   [2.023183e+08]
# Correlacion cruzada en rotación:  1.08   [2.0230203e+08]
# Correlacion cruzada en rotación:  1.11   [2.0228618e+08]
# Correlacion cruzada en rotación:  1.1400000000000001   [2.0226922e+08]
# Correlacion cruzada en rotación:  1.17   [2.0224734e+08]
# Correlacion cruzada en rotación:  1.2000000000000002   [2.022184e+08]
# La segunda rotación es:  [0.6]
#
#
# Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  1.2449999999999999   [1.687391e+08]
# Correlacion cruzada en escala:  1.2454999999999998   [1.6878746e+08]
# Correlacion cruzada en escala:  1.2459999999999998   [1.688397e+08]
# Correlacion cruzada en escala:  1.2465   [1.6887877e+08]
# Correlacion cruzada en escala:  1.2469999999999999   [1.689205e+08]
# Correlacion cruzada en escala:  1.2474999999999998   [1.689427e+08]
# Correlacion cruzada en escala:  1.2479999999999998   [1.6898925e+08]
# Correlacion cruzada en escala:  1.2485   [1.6902606e+08]
# Correlacion cruzada en escala:  1.2489999999999999   [1.690715e+08]
# Correlacion cruzada en escala:  1.2494999999999998   [1.6910717e+08]
# Correlacion cruzada en escala:  1.2499999999999998   [1.6915912e+08]
# Correlacion cruzada en escala:  1.2505   [1.6918358e+08]
# Correlacion cruzada en escala:  1.251   [1.692248e+08]
# Correlacion cruzada en escala:  1.2514999999999998   [1.69267e+08]
# Correlacion cruzada en escala:  1.2519999999999998   [1.6930058e+08]
# Correlacion cruzada en escala:  1.2525   [1.6933643e+08]
# Correlacion cruzada en escala:  1.253   [1.6938502e+08]
# Correlacion cruzada en escala:  1.2534999999999998   [1.6940192e+08]
# Correlacion cruzada en escala:  1.2539999999999998   [1.6945064e+08]
# Correlacion cruzada en escala:  1.2545   [1.6946376e+08]
# Correlacion cruzada en escala:  1.255   [1.6951296e+08]
# La tercera escala es:  [1.255]
# Correlacion cruzada en traslacion x:  [9.1]   [1.9983034e+08]
# Correlacion cruzada en traslacion x:  [9.555]   [2.0041088e+08]
# Correlacion cruzada en traslacion x:  [10.01]   [2.0077621e+08]
# Correlacion cruzada en traslacion x:  [10.465]   [2.0108371e+08]
# Correlacion cruzada en traslacion x:  [10.92]   [2.0157592e+08]
# Correlacion cruzada en traslacion x:  [11.375]   [2.0187856e+08]
# Correlacion cruzada en traslacion x:  [11.83]   [2.0216032e+08]
# Correlacion cruzada en traslacion x:  [12.285]   [2.0234496e+08]
# Correlacion cruzada en traslacion x:  [12.74]   [2.0274669e+08]
# Correlacion cruzada en traslacion x:  [13.195]   [2.0263462e+08]
# Correlacion cruzada en traslacion x:  [13.65]   [2.0270403e+08]
# Correlacion cruzada en traslacion x:  [14.105]   [2.0273694e+08]
# Correlacion cruzada en traslacion x:  [14.56]   [2.0284824e+08]
# Correlacion cruzada en traslacion x:  [15.015]   [2.0280451e+08]
# Correlacion cruzada en traslacion x:  [15.47]   [2.0266547e+08]
# Correlacion cruzada en traslacion x:  [15.925]   [2.02678e+08]
# Correlacion cruzada en traslacion x:  [16.38]   [2.0253408e+08]
# Correlacion cruzada en traslacion x:  [16.835]   [2.0231517e+08]
# Correlacion cruzada en traslacion x:  [17.29]   [2.0204894e+08]
# Correlacion cruzada en traslacion x:  [17.745]   [2.0197638e+08]
# Correlacion cruzada en traslacion x:  [18.2]   [2.0141829e+08]
# La tercera traslacion es:  [14.56]
# Correlacion cruzada en traslacion y:  [-9.1]   [2.032038e+08]
# Correlacion cruzada en traslacion y:  [-8.645]   [2.03291e+08]
# Correlacion cruzada en traslacion y:  [-8.19]   [2.0354118e+08]
# Correlacion cruzada en traslacion y:  [-7.735]   [2.0377866e+08]
# Correlacion cruzada en traslacion y:  [-7.28]   [2.0368882e+08]
# Correlacion cruzada en traslacion y:  [-6.825]   [2.0370614e+08]
# Correlacion cruzada en traslacion y:  [-6.37]   [2.0391632e+08]
# Correlacion cruzada en traslacion y:  [-5.915]   [2.0387715e+08]
# Correlacion cruzada en traslacion y:  [-5.46]   [2.0393635e+08]
# Correlacion cruzada en traslacion y:  [-5.005]   [2.0391826e+08]
# Correlacion cruzada en traslacion y:  [-4.55]   [2.0389928e+08]
# Correlacion cruzada en traslacion y:  [-4.095]   [2.0389213e+08]
# Correlacion cruzada en traslacion y:  [-3.64]   [2.0392475e+08]
# Correlacion cruzada en traslacion y:  [-3.185]   [2.0389784e+08]
# Correlacion cruzada en traslacion y:  [-2.73]   [2.0371584e+08]
# Correlacion cruzada en traslacion y:  [-2.275]   [2.036947e+08]
# Correlacion cruzada en traslacion y:  [-1.82]   [2.0351496e+08]
# Correlacion cruzada en traslacion y:  [-1.365]   [2.0351234e+08]
# Correlacion cruzada en traslacion y:  [-0.91]   [2.03277e+08]
# Correlacion cruzada en traslacion y:  [-0.455]   [2.0308093e+08]
# Correlacion cruzada en traslacion y:  [-2.30926389e-14]   [2.0284824e+08]
# La tercera traslacion es:  [-5.46]
# Correlacion cruzada en rotación:  0.5700000000000003   [2.0309115e+08]
# Correlacion cruzada en rotación:  0.5730000000000003   [2.0308974e+08]
# Correlacion cruzada en rotación:  0.5760000000000003   [2.0309152e+08]
# Correlacion cruzada en rotación:  0.5790000000000003   [2.030897e+08]
# Correlacion cruzada en rotación:  0.5820000000000003   [2.030909e+08]
# Correlacion cruzada en rotación:  0.5850000000000003   [2.0308712e+08]
# Correlacion cruzada en rotación:  0.5880000000000003   [2.0308501e+08]
# Correlacion cruzada en rotación:  0.5910000000000003   [2.0307885e+08]
# Correlacion cruzada en rotación:  0.5940000000000003   [2.0307446e+08]
# Correlacion cruzada en rotación:  0.5970000000000003   [2.03072e+08]
# Correlacion cruzada en rotación:  0.6000000000000003   [2.0307349e+08]
# Correlacion cruzada en rotación:  0.6030000000000003   [2.0308501e+08]
# Correlacion cruzada en rotación:  0.6060000000000003   [2.0308379e+08]
# Correlacion cruzada en rotación:  0.6090000000000003   [2.030854e+08]
# Correlacion cruzada en rotación:  0.6120000000000003   [2.0308261e+08]
# Correlacion cruzada en rotación:  0.6150000000000003   [2.0307942e+08]
# Correlacion cruzada en rotación:  0.6180000000000003   [2.0307768e+08]
# Correlacion cruzada en rotación:  0.6210000000000003   [2.0307568e+08]
# Correlacion cruzada en rotación:  0.6240000000000003   [2.03077e+08]
# Correlacion cruzada en rotación:  0.6270000000000003   [2.0307432e+08]
# Correlacion cruzada en rotación:  0.6300000000000003   [2.0307542e+08]
# La tercera rotación es:  [0.576]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f98ced85fd0>,
#  <matplotlib.image.AxesImage at 0x7f98ced5f750>,
#  Text(0.5, 1.0, 'Registro Completo'))

# %% [markdown]
# Resultados en BGR

# %%
# Mostrando el resultado final en BGR #

presion_BGR= cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift_BGR.JPG")
print(presion_BGR.shape)
(presion_B,presion_G,presion_R) = cv2.split(presion_BGR)

rows, cols, channels = presion_BGR.shape

M_escala = cv2.getRotationMatrix2D((cols/2,rows/2),0,s3)
M_traslacion_x = np.float32([[1,0,x3],[0,1,0]])
M_traslacion_y = np.float32([[1,0,0],[0,1,y3]])
M_rotacion = cv2.getRotationMatrix2D((cols/2,rows/2),r3,1)

presion_B = cv2.warpAffine(presion_B, M_escala, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_x, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_y, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_rotacion, (cols,rows))

presion_G = cv2.warpAffine(presion_G, M_escala, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_x, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_y, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_rotacion, (cols,rows))

presion_R = cv2.warpAffine(presion_R, M_escala, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_x, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_y, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_rotacion, (cols,rows))

presion_BGR_registro = cv2.merge([presion_B,presion_G,presion_R])

imagen1_RGB = cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
presion_RGB_registro = cv2.cvtColor(presion_BGR_registro, cv2.COLOR_BGR2RGB)

plt.figure(12)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')

cv2_imshow(imagen1)
cv2_imshow(presion_BGR_registro)
# Out:
# (455, 455, 3)
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7F98CEEF0990>
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7F98CE484BD0>

# %% [markdown]
# Salida de imagen

# %%
Salida_registro = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_CCORR.JPG",imagen2_sxyr3)
Salida_registro_BGR = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_BGR_CCORR.JPG",presion_BGR_registro)
