# %% [markdown]
# <a href="https://colab.research.google.com/github/yeisonluna/RegistroMultimodal/blob/main/Registro_Multimodal_CCORR_Multiescala_v_final_Yeison_Luna_TG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGISTRO MULTIMODAL DE IMÁGENES CON CORRELACION CRUZADA - BÚSQUEDA MULTIESCALA**
#
#
#
# ---

# %% [markdown]
# Importación de Bibliotecas

# %%
import numpy as np  #paquete de arreglos
import matplotlib as pyplot 
import matplotlib.pyplot as plt  # paquete de gráficos
import cv2 
from google.colab.patches import cv2_imshow # para imprimir imágenes

# %% [markdown]
# Se importan las imágenes, guardadas en un drive de google.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importación de Imágenes

# %%
plt.style.use('ggplot')
imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PodoscopioPreProcesadaFinalIzq.JPG")
imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PresionPreProcesadaFinalIzq.JPG")
#imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Podoscopio_preprocesada_total.JPG")
#imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift.TIFF")

# %% [markdown]
# # Funciones del algoritmo

# %% [markdown]
# Funcion multiescala

# %%
def scale_img_1(im1, im2):
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 
    escala_max = 1

# ----------------------------------- Ciclo 1 -------------------------------- #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = escala_max/n_int
        b1 = 0.2
        f = float(m1*i+b1)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,f)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]
            
        NCC_1.append(ncc)
        print("Correlacion cruzada en escala: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    scale = np.where(NCC_1==max(NCC_1))
    escala = scale[0]
    
    print("La primera escala es: ",m1*escala+b1)

    funcion_final = float(m1*escala)
    

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala 

def scale_img_2(im1,im2,escala):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]
    escala_max = 1

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
        

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*escala_max/(n_int**2)
        b2 = 0.2 + escala_max*(escala-1)/n_int 
        g = float(m2*j+b2)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,g)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en escala: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    scale_2 = np.where(NCC_2==max(NCC_2))
    escala_2 = scale_2[0]
    
    print("La segunda escala es: ",m2*escala_2+b2)

    funcion_final = float(m2*escala_2+b2)    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala_2
    

def scale_img_3(im1,im2,escala,escala_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    escala_max = 1


    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)


        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 4*escala_max/(n_int**3)
        b3 = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
        h = float(m3*k+b3)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,h)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en escala: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    scale_3 = np.where(NCC_3==max(NCC_3))
    escala_3 = scale_3[0]
    
    print("La tercera escala es: ",m3*escala_3+b3)
    
    m_final = 4*escala_max/(n_int**3)
    b_final = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
    funcion_final = float(m_final*escala_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funciones de traslacion

# %%
def shift_img_x_1(im1, im2):
    
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    
    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*cols/n_int   
        b1 = 0-cols
        f = (m1*i + b1)
            
        shift_matrix_x_axis = np.float32([[1,0,f],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en traslacion x: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_x = np.where(NCC_1==max(NCC_1))
    traslacion_x = shift_x[0]
    
    print("La primera traslacion es: ",m1*traslacion_x+b1)

    funcion_final = (m1*traslacion_x+b1) 
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x

def shift_img_x_2(im1, im2, traslacion_x):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]

    for j in range (n_int+1): 
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2 

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*cols)/(n_int**2)
        b2 = (2*cols*(traslacion_x-1))/n_int - (cols)
        g = (m2*j+b2)
                
        shift_matrix_x_axis = np.float32([[1,0,g],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en traslacion x: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_x_2 = np.where(NCC_2==max(NCC_2))
    traslacion_x_2 = shift_x_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_x_2+b2)

    funcion_final = (m2*traslacion_x_2+b2)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x_2

def shift_img_x_3(im1,im2,traslacion_x,traslacion_x_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*cols)/(n_int**3)
        b3 = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
        h = (m3*k+b3)
                
        shift_matrix_x_axis = np.float32([[1,0,h],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en traslacion x: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_x_3 = np.where(NCC_3==max(NCC_3))
    traslacion_x_3 = shift_x_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_x_3+b3)
    

    m_final = 2*(4*cols)/(n_int**3)
    b_final = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
    funcion_final = (m_final*traslacion_x_3+b_final)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de traslación en y

# %%
def shift_img_y_1(im1, im2):   
   
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 

    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*rows/n_int   
        b1 = 0-rows
        f = (m1*i + b1)
            
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,f]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en traslacion y: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_y = np.where(NCC_1==max(NCC_1))
    traslacion_y = shift_y[0]
    
    print("La primera traslacion es: ",m1*traslacion_y+b1)

    funcion_final = (m1*traslacion_y + b1)    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y


def shift_img_y_2(im1,im2,traslacion_y):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]


    for j in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*rows)/(n_int**2)
        b2 = (2*rows*(traslacion_y-1))/n_int - (rows)
        g = (m2*j+b2)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,g]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            

            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en traslacion y: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_y_2 = np.where(NCC_2==max(NCC_2))
    traslacion_y_2 = shift_y_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_y_2+b2)

    funcion_final = (m2*traslacion_y_2+b2)     

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y_2

def shift_img_y_3(im1,im2,traslacion_y,traslacion_y_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*rows)/(n_int**3)
        b3 = 2*(2*rows)*(traslacion_y_2-1)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
        h = (m3*k+b3)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,h]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en traslacion y: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_y_3 = np.where(NCC_3==max(NCC_3))
    traslacion_y_3 = shift_y_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_y_3+b3)
    

    m_final = 2*(4*rows)/(n_int**3)
    b_final = 2*(2*rows)*(traslacion_y_2)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
    funcion_final = (m_final*traslacion_y_3+b_final)
    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de rotación

# %%
def rotation_matrix_1(im1, im2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1 = []
    angulo_max = 3

# ----------------------------------- Ciclo 1 ------------------------------------ #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*angulo_max/n_int
        b1 = 0-angulo_max
        f = float(m1*i+b1)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),f,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada en rotacion: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    angle = np.where(NCC_1==max(NCC_1))
    angulo = angle[0]
    
    print("La primera rotación es: ",m1*angulo+b1)

    funcion_final = float(m1*angulo+b1)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo

def rotation_matrix_2(im1, im2, angulo):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2 = []
    angulo_max = 3

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*2*angulo_max/(n_int**2)
        b2 = 2*angulo_max*(angulo-1)/n_int - angulo_max
        g = float(m2*j+b2)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),g,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada en rotación: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    angle_2 = np.where(NCC_2==max(NCC_2))
    angulo_2 = angle_2[0]
    
    print("La segunda rotación es: ",m2*angulo_2+b2)

    funcion_final = float(m2*angulo_2+b2)
     

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo_2

def rotation_matrix_3(im1, im2, angulo, angulo_2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    angulo_max = 3

    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*4*angulo_max/(n_int**3)
        b3 = 2*angulo_max*(angulo-1)/n_int + 2*2*angulo_max*(angulo_2-1)/(n_int**2) - angulo_max
        h = float(m3*k+b3)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),h,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada en rotación: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    angle_3 = np.where(NCC_3==max(NCC_3))
    angulo_3 = angle_3[0]
    
    print("La tercera rotación es: ",m3*angulo_3+b3)
    
    m_final = 2*4*angulo_max/(n_int**3)
    b_final = angulo_max*(angulo-1)/n_int + 2*angulo_max*(angulo_2-1)/(n_int**2)
    funcion_final = float(m_final*angulo_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funcion de información mutua

# %%
def mutual_information(hgram):
   # Convertir los recuentos de los rangos en valores de probabilidad
    pxy = hgram / float(np.sum(hgram))
    px = np.sum(pxy, axis=1) # marginal para x sobre y
    py = np.sum(pxy, axis=0) # marginal para y sobre x
    px_py = px[:, None] * py[None, :] # multiplicar probabilidades 
    # Ahora podemos hacer el cálculo usando las matrices 2D pxy, px_py
    nzs = pxy > 0 # Solo valores no nulos en la suma
    return np.sum(pxy[nzs] * np.log(pxy[nzs] / px_py[nzs]))

# %% [markdown]
# # Resultados

# %%
#----------------------------------------------------------------------------------------#
#Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s1, s1 = scale_img_1(imagen1, imagen2)

plt.figure(0)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s1,'gray'),plt.title('S1')

imagen2_sx1, x1 = shift_img_x_1(imagen1, imagen2_s1)

plt.figure(1)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx1,'gray'),plt.title('S1, X1')

imagen2_sxy1, y1 = shift_img_y_1(imagen1, imagen2_sx1)

plt.figure(2)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy1,'gray'),plt.title('S1, X1, Y1')

imagen2_sxyr1, r1 = rotation_matrix_1(imagen1, imagen2_sxy1)

plt.figure(3)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr1,'gray'),plt.title('S1, X1, Y1, R1')

print("\n")

#----------------------------------------------------------------------------------------#
#Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
print("Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s2, s2 = scale_img_2(imagen1, imagen2, s1)

plt.figure(4)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s2,'gray'),plt.title('S2')

imagen2_sx2, x2 = shift_img_x_2(imagen1, imagen2_s2, x1)

plt.figure(5)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx2,'gray'),plt.title('S2, X2')

imagen2_sxy2, y2 = shift_img_y_2(imagen1, imagen2_sx2, y1)

plt.figure(6)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy2,'gray'),plt.title('S2, X2, Y2')


imagen2_sxyr2, r2 = rotation_matrix_2(imagen1, imagen2_sxy2, r1)

plt.figure(7)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr2,'gray'),plt.title('S2, X2, Y2, R2')

print("\n")

#----------------------------------------------------------------------------------------#
#Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s3, s3 = scale_img_3(imagen1, imagen2, s1, s2)

plt.figure(8)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s3,'gray'),plt.title('S3')

imagen2_sx3, x3 = shift_img_x_3(imagen1, imagen2_s3, x1, x2)

plt.figure(9)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx3,'gray'),plt.title('S3, X3')

imagen2_sxy3, y3 = shift_img_y_3(imagen1, imagen2_sx3, y1, y2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy3,'gray'),plt.title('S3, X3, Y3')


imagen2_sxyr3, r3 = rotation_matrix_3(imagen1, imagen2_sxy3, r1, r2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('S3, X3, Y3, R3')



#----------------------------------------------------------------------------------------#
# Mostrando el resultado final #


plt.figure(11)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('Original')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('Registro Completo')
# Out:
# Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  0.2   [14535166.]
# Correlacion cruzada en escala:  0.25   [24703018.]
# Correlacion cruzada en escala:  0.30000000000000004   [37976940.]
# Correlacion cruzada en escala:  0.35000000000000003   [54782900.]
# Correlacion cruzada en escala:  0.4   [75080664.]
# Correlacion cruzada en escala:  0.45   [98696160.]
# Correlacion cruzada en escala:  0.5   [1.2586886e+08]
# Correlacion cruzada en escala:  0.55   [1.5588094e+08]
# Correlacion cruzada en escala:  0.6000000000000001   [1.8919843e+08]
# Correlacion cruzada en escala:  0.65   [2.2534294e+08]
# Correlacion cruzada en escala:  0.7   [2.6387667e+08]
# Correlacion cruzada en escala:  0.75   [3.043e+08]
# Correlacion cruzada en escala:  0.8   [3.448843e+08]
# Correlacion cruzada en escala:  0.8500000000000001   [3.8523533e+08]
# Correlacion cruzada en escala:  0.9000000000000001   [4.2661654e+08]
# Correlacion cruzada en escala:  0.95   [4.679577e+08]
# Correlacion cruzada en escala:  1.0   [5.0736954e+08]
# Correlacion cruzada en escala:  1.05   [5.403423e+08]
# Correlacion cruzada en escala:  1.1   [5.642468e+08]
# Correlacion cruzada en escala:  1.1500000000000001   [5.8141037e+08]
# Correlacion cruzada en escala:  1.2   [5.943202e+08]
# La primera escala es:  [1.2]
# Correlacion cruzada en traslacion x:  -455.0   [0.]
# Correlacion cruzada en traslacion x:  -409.5   [0.]
# Correlacion cruzada en traslacion x:  -364.0   [0.]
# Correlacion cruzada en traslacion x:  -318.5   [673378.]
# Correlacion cruzada en traslacion x:  -273.0   [28169754.]
# Correlacion cruzada en traslacion x:  -227.5   [56884492.]
# Correlacion cruzada en traslacion x:  -182.0   [97611810.]
# Correlacion cruzada en traslacion x:  -136.5   [1.3594973e+08]
# Correlacion cruzada en traslacion x:  -91.0   [1.7502562e+08]
# Correlacion cruzada en traslacion x:  -45.5   [3.5397056e+08]
# Correlacion cruzada en traslacion x:  0.0   [5.943202e+08]
# Correlacion cruzada en traslacion x:  45.5   [5.405503e+08]
# Correlacion cruzada en traslacion x:  91.0   [2.716546e+08]
# Correlacion cruzada en traslacion x:  136.5   [1.276621e+08]
# Correlacion cruzada en traslacion x:  182.0   [99174320.]
# Correlacion cruzada en traslacion x:  227.5   [72648700.]
# Correlacion cruzada en traslacion x:  273.0   [39288332.]
# Correlacion cruzada en traslacion x:  318.5   [8007846.5]
# Correlacion cruzada en traslacion x:  364.0   [58.999966]
# Correlacion cruzada en traslacion x:  409.5   [0.]
# Correlacion cruzada en traslacion x:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada en traslacion y:  -455.0   [0.]
# Correlacion cruzada en traslacion y:  -409.5   [13279039.]
# Correlacion cruzada en traslacion y:  -364.0   [47383516.]
# Correlacion cruzada en traslacion y:  -318.5   [98828640.]
# Correlacion cruzada en traslacion y:  -273.0   [1.5223506e+08]
# Correlacion cruzada en traslacion y:  -227.5   [1.9296469e+08]
# Correlacion cruzada en traslacion y:  -182.0   [2.26096e+08]
# Correlacion cruzada en traslacion y:  -136.5   [2.927864e+08]
# Correlacion cruzada en traslacion y:  -91.0   [4.5461328e+08]
# Correlacion cruzada en traslacion y:  -45.5   [6.1505683e+08]
# Correlacion cruzada en traslacion y:  0.0   [5.943202e+08]
# Correlacion cruzada en traslacion y:  45.5   [4.3535408e+08]
# Correlacion cruzada en traslacion y:  91.0   [2.8216218e+08]
# Correlacion cruzada en traslacion y:  136.5   [2.1105358e+08]
# Correlacion cruzada en traslacion y:  182.0   [1.6184632e+08]
# Correlacion cruzada en traslacion y:  227.5   [1.22050584e+08]
# Correlacion cruzada en traslacion y:  273.0   [74010750.]
# Correlacion cruzada en traslacion y:  318.5   [21816798.]
# Correlacion cruzada en traslacion y:  364.0   [9309933.]
# Correlacion cruzada en traslacion y:  409.5   [1234917.4]
# Correlacion cruzada en traslacion y:  455.0   [0.]
# La primera traslacion es:  [-45.5]
# Correlacion cruzada en rotacion:  -3.0   [6.2444154e+08]
# Correlacion cruzada en rotacion:  -2.7   [6.23892e+08]
# Correlacion cruzada en rotacion:  -2.4   [6.232636e+08]
# Correlacion cruzada en rotacion:  -2.1   [6.225611e+08]
# Correlacion cruzada en rotacion:  -1.8   [6.217045e+08]
# Correlacion cruzada en rotacion:  -1.5   [6.2087066e+08]
# Correlacion cruzada en rotacion:  -1.2000000000000002   [6.199043e+08]
# Correlacion cruzada en rotacion:  -0.8999999999999999   [6.188518e+08]
# Correlacion cruzada en rotacion:  -0.6000000000000001   [6.176364e+08]
# Correlacion cruzada en rotacion:  -0.30000000000000027   [6.164197e+08]
# Correlacion cruzada en rotacion:  0.0   [6.1505683e+08]
# Correlacion cruzada en rotacion:  0.2999999999999998   [6.136194e+08]
# Correlacion cruzada en rotacion:  0.5999999999999996   [6.121093e+08]
# Correlacion cruzada en rotacion:  0.8999999999999999   [6.104115e+08]
# Correlacion cruzada en rotacion:  1.2000000000000002   [6.086727e+08]
# Correlacion cruzada en rotacion:  1.5   [6.0683584e+08]
# Correlacion cruzada en rotacion:  1.7999999999999998   [6.048869e+08]
# Correlacion cruzada en rotacion:  2.0999999999999996   [6.0288966e+08]
# Correlacion cruzada en rotacion:  2.3999999999999995   [6.008058e+08]
# Correlacion cruzada en rotacion:  2.7   [5.987357e+08]
# Correlacion cruzada en rotacion:  3.0   [5.965556e+08]
# La primera rotación es:  [-3.]
#
#
# Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  1.15   [5.8141037e+08]
# Correlacion cruzada en escala:  1.1549999999999998   [5.8292384e+08]
# Correlacion cruzada en escala:  1.16   [5.8429504e+08]
# Correlacion cruzada en escala:  1.1649999999999998   [5.8566675e+08]
# Correlacion cruzada en escala:  1.17   [5.8698054e+08]
# Correlacion cruzada en escala:  1.1749999999999998   [5.8828614e+08]
# Correlacion cruzada en escala:  1.18   [5.8953536e+08]
# Correlacion cruzada en escala:  1.1849999999999998   [5.907897e+08]
# Correlacion cruzada en escala:  1.19   [5.9192755e+08]
# Correlacion cruzada en escala:  1.1949999999999998   [5.931111e+08]
# Correlacion cruzada en escala:  1.2   [5.943202e+08]
# Correlacion cruzada en escala:  1.2049999999999998   [5.954205e+08]
# Correlacion cruzada en escala:  1.21   [5.965403e+08]
# Correlacion cruzada en escala:  1.2149999999999999   [5.976907e+08]
# Correlacion cruzada en escala:  1.22   [5.9876224e+08]
# Correlacion cruzada en escala:  1.2249999999999999   [5.998653e+08]
# Correlacion cruzada en escala:  1.23   [6.010198e+08]
# Correlacion cruzada en escala:  1.2349999999999999   [6.0208454e+08]
# Correlacion cruzada en escala:  1.24   [6.031429e+08]
# Correlacion cruzada en escala:  1.2449999999999999   [6.042939e+08]
# Correlacion cruzada en escala:  1.25   [6.0545094e+08]
# La segunda escala es:  [1.25]
# Correlacion cruzada en traslacion x:  [-45.5]   [4.214361e+08]
# Correlacion cruzada en traslacion x:  [-40.95]   [4.423665e+08]
# Correlacion cruzada en traslacion x:  [-36.4]   [4.6540406e+08]
# Correlacion cruzada en traslacion x:  [-31.85]   [4.876807e+08]
# Correlacion cruzada en traslacion x:  [-27.3]   [5.1082698e+08]
# Correlacion cruzada en traslacion x:  [-22.75]   [5.3462922e+08]
# Correlacion cruzada en traslacion x:  [-18.2]   [5.575486e+08]
# Correlacion cruzada en traslacion x:  [-13.65]   [5.8007014e+08]
# Correlacion cruzada en traslacion x:  [-9.1]   [6.0312096e+08]
# Correlacion cruzada en traslacion x:  [-4.55]   [6.238898e+08]
# Correlacion cruzada en traslacion x:  [0.]   [6.4402054e+08]
# Correlacion cruzada en traslacion x:  [4.55]   [6.6197235e+08]
# Correlacion cruzada en traslacion x:  [9.1]   [6.765009e+08]
# Correlacion cruzada en traslacion x:  [13.65]   [6.8946944e+08]
# Correlacion cruzada en traslacion x:  [18.2]   [6.9879405e+08]
# Correlacion cruzada en traslacion x:  [22.75]   [7.0740915e+08]
# Correlacion cruzada en traslacion x:  [27.3]   [7.11827e+08]
# Correlacion cruzada en traslacion x:  [31.85]   [7.1445805e+08]
# Correlacion cruzada en traslacion x:  [36.4]   [7.138394e+08]
# Correlacion cruzada en traslacion x:  [40.95]   [7.115617e+08]
# Correlacion cruzada en traslacion x:  [45.5]   [7.091661e+08]
# La segunda traslacion es:  [31.85]
# Correlacion cruzada en traslacion y:  [-91.]   [5.53066e+08]
# Correlacion cruzada en traslacion y:  [-86.45]   [5.7487814e+08]
# Correlacion cruzada en traslacion y:  [-81.9]   [5.95482e+08]
# Correlacion cruzada en traslacion y:  [-77.35]   [6.164201e+08]
# Correlacion cruzada en traslacion y:  [-72.8]   [6.356233e+08]
# Correlacion cruzada en traslacion y:  [-68.25]   [6.552116e+08]
# Correlacion cruzada en traslacion y:  [-63.7]   [6.727505e+08]
# Correlacion cruzada en traslacion y:  [-59.15]   [6.908715e+08]
# Correlacion cruzada en traslacion y:  [-54.6]   [7.075159e+08]
# Correlacion cruzada en traslacion y:  [-50.05]   [7.214906e+08]
# Correlacion cruzada en traslacion y:  [-45.5]   [7.332973e+08]
# Correlacion cruzada en traslacion y:  [-40.95]   [7.3819245e+08]
# Correlacion cruzada en traslacion y:  [-36.4]   [7.4237203e+08]
# Correlacion cruzada en traslacion y:  [-31.85]   [7.439303e+08]
# Correlacion cruzada en traslacion y:  [-27.3]   [7.4396326e+08]
# Correlacion cruzada en traslacion y:  [-22.75]   [7.42307e+08]
# Correlacion cruzada en traslacion y:  [-18.2]   [7.377657e+08]
# Correlacion cruzada en traslacion y:  [-13.65]   [7.3297344e+08]
# Correlacion cruzada en traslacion y:  [-9.1]   [7.275238e+08]
# Correlacion cruzada en traslacion y:  [-4.55]   [7.2135565e+08]
# Correlacion cruzada en traslacion y:  [0.]   [7.1445805e+08]
# La segunda traslacion es:  [-27.3]
# Correlacion cruzada en rotación:  -3.3   [7.489967e+08]
# Correlacion cruzada en rotación:  -3.27   [7.4900205e+08]
# Correlacion cruzada en rotación:  -3.2399999999999998   [7.489899e+08]
# Correlacion cruzada en rotación:  -3.21   [7.489802e+08]
# Correlacion cruzada en rotación:  -3.1799999999999997   [7.489811e+08]
# Correlacion cruzada en rotación:  -3.15   [7.489629e+08]
# Correlacion cruzada en rotación:  -3.1199999999999997   [7.4893843e+08]
# Correlacion cruzada en rotación:  -3.09   [7.489294e+08]
# Correlacion cruzada en rotación:  -3.0599999999999996   [7.4893216e+08]
# Correlacion cruzada en rotación:  -3.03   [7.489125e+08]
# Correlacion cruzada en rotación:  -3.0   [7.489078e+08]
# Correlacion cruzada en rotación:  -2.9699999999999998   [7.489e+08]
# Correlacion cruzada en rotación:  -2.94   [7.4888774e+08]
# Correlacion cruzada en rotación:  -2.9099999999999997   [7.488703e+08]
# Correlacion cruzada en rotación:  -2.88   [7.488522e+08]
# Correlacion cruzada en rotación:  -2.8499999999999996   [7.488438e+08]
# Correlacion cruzada en rotación:  -2.82   [7.488148e+08]
# Correlacion cruzada en rotación:  -2.79   [7.488212e+08]
# Correlacion cruzada en rotación:  -2.76   [7.488021e+08]
# Correlacion cruzada en rotación:  -2.73   [7.4877235e+08]
# Correlacion cruzada en rotación:  -2.6999999999999997   [7.487758e+08]
# La segunda rotación es:  [-3.27]
#
#
# Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada en escala:  1.2449999999999999   [6.042939e+08]
# Correlacion cruzada en escala:  1.2454999999999998   [6.0439994e+08]
# Correlacion cruzada en escala:  1.2459999999999998   [6.0448736e+08]
# Correlacion cruzada en escala:  1.2465   [6.0459315e+08]
# Correlacion cruzada en escala:  1.2469999999999999   [6.0468986e+08]
# Correlacion cruzada en escala:  1.2474999999999998   [6.048051e+08]
# Correlacion cruzada en escala:  1.2479999999999998   [6.0492685e+08]
# Correlacion cruzada en escala:  1.2485   [6.0505414e+08]
# Correlacion cruzada en escala:  1.2489999999999999   [6.0517664e+08]
# Correlacion cruzada en escala:  1.2494999999999998   [6.052698e+08]
# Correlacion cruzada en escala:  1.2499999999999998   [6.0545094e+08]
# Correlacion cruzada en escala:  1.2505   [6.054794e+08]
# Correlacion cruzada en escala:  1.251   [6.055899e+08]
# Correlacion cruzada en escala:  1.2514999999999998   [6.056776e+08]
# Correlacion cruzada en escala:  1.2519999999999998   [6.0580314e+08]
# Correlacion cruzada en escala:  1.2525   [6.059103e+08]
# Correlacion cruzada en escala:  1.253   [6.060164e+08]
# Correlacion cruzada en escala:  1.2534999999999998   [6.060923e+08]
# Correlacion cruzada en escala:  1.2539999999999998   [6.0622656e+08]
# Correlacion cruzada en escala:  1.2545   [6.062989e+08]
# Correlacion cruzada en escala:  1.255   [6.064468e+08]
# La tercera escala es:  [1.255]
# Correlacion cruzada en traslacion x:  [27.3]   [7.134386e+08]
# Correlacion cruzada en traslacion x:  [27.755]   [7.146816e+08]
# Correlacion cruzada en traslacion x:  [28.21]   [7.139131e+08]
# Correlacion cruzada en traslacion x:  [28.665]   [7.1461626e+08]
# Correlacion cruzada en traslacion x:  [29.12]   [7.1476826e+08]
# Correlacion cruzada en traslacion x:  [29.575]   [7.1543846e+08]
# Correlacion cruzada en traslacion x:  [30.03]   [7.15402e+08]
# Correlacion cruzada en traslacion x:  [30.485]   [7.174998e+08]
# Correlacion cruzada en traslacion x:  [30.94]   [7.158772e+08]
# Correlacion cruzada en traslacion x:  [31.395]   [7.158021e+08]
# Correlacion cruzada en traslacion x:  [31.85]   [7.163907e+08]
# Correlacion cruzada en traslacion x:  [32.305]   [7.162399e+08]
# Correlacion cruzada en traslacion x:  [32.76]   [7.172069e+08]
# Correlacion cruzada en traslacion x:  [33.215]   [7.161464e+08]
# Correlacion cruzada en traslacion x:  [33.67]   [7.165473e+08]
# Correlacion cruzada en traslacion x:  [34.125]   [7.164489e+08]
# Correlacion cruzada en traslacion x:  [34.58]   [7.166994e+08]
# Correlacion cruzada en traslacion x:  [35.035]   [7.1649766e+08]
# Correlacion cruzada en traslacion x:  [35.49]   [7.1830944e+08]
# Correlacion cruzada en traslacion x:  [35.945]   [7.163748e+08]
# Correlacion cruzada en traslacion x:  [36.4]   [7.160694e+08]
# La tercera traslacion es:  [35.49]
# Correlacion cruzada en traslacion y:  [-31.85]   [7.438974e+08]
# Correlacion cruzada en traslacion y:  [-31.395]   [7.4411994e+08]
# Correlacion cruzada en traslacion y:  [-30.94]   [7.440754e+08]
# Correlacion cruzada en traslacion y:  [-30.485]   [7.45983e+08]
# Correlacion cruzada en traslacion y:  [-30.03]   [7.441329e+08]
# Correlacion cruzada en traslacion y:  [-29.575]   [7.440614e+08]
# Correlacion cruzada en traslacion y:  [-29.12]   [7.4439405e+08]
# Correlacion cruzada en traslacion y:  [-28.665]   [7.440205e+08]
# Correlacion cruzada en traslacion y:  [-28.21]   [7.441196e+08]
# Correlacion cruzada en traslacion y:  [-27.755]   [7.447424e+08]
# Correlacion cruzada en traslacion y:  [-27.3]   [7.4420224e+08]
# Correlacion cruzada en traslacion y:  [-26.845]   [7.439781e+08]
# Correlacion cruzada en traslacion y:  [-26.39]   [7.4416275e+08]
# Correlacion cruzada en traslacion y:  [-25.935]   [7.437811e+08]
# Correlacion cruzada en traslacion y:  [-25.48]   [7.437002e+08]
# Correlacion cruzada en traslacion y:  [-25.025]   [7.4342074e+08]
# Correlacion cruzada en traslacion y:  [-24.57]   [7.4318586e+08]
# Correlacion cruzada en traslacion y:  [-24.115]   [7.432447e+08]
# Correlacion cruzada en traslacion y:  [-23.66]   [7.426879e+08]
# Correlacion cruzada en traslacion y:  [-23.205]   [7.425238e+08]
# Correlacion cruzada en traslacion y:  [-22.75]   [7.429773e+08]
# La tercera traslacion es:  [-30.485]
# Correlacion cruzada en rotación:  -3.3   [7.476943e+08]
# Correlacion cruzada en rotación:  -3.2969999999999997   [7.476897e+08]
# Correlacion cruzada en rotación:  -3.294   [7.476943e+08]
# Correlacion cruzada en rotación:  -3.291   [7.476966e+08]
# Correlacion cruzada en rotación:  -3.288   [7.47695e+08]
# Correlacion cruzada en rotación:  -3.2849999999999997   [7.476865e+08]
# Correlacion cruzada en rotación:  -3.282   [7.476895e+08]
# Correlacion cruzada en rotación:  -3.279   [7.476927e+08]
# Correlacion cruzada en rotación:  -3.276   [7.4769254e+08]
# Correlacion cruzada en rotación:  -3.2729999999999997   [7.47691e+08]
# Correlacion cruzada en rotación:  -3.27   [7.476838e+08]
# Correlacion cruzada en rotación:  -3.267   [7.4768774e+08]
# Correlacion cruzada en rotación:  -3.264   [7.476899e+08]
# Correlacion cruzada en rotación:  -3.2609999999999997   [7.476907e+08]
# Correlacion cruzada en rotación:  -3.258   [7.4768365e+08]
# Correlacion cruzada en rotación:  -3.255   [7.476784e+08]
# Correlacion cruzada en rotación:  -3.252   [7.4767795e+08]
# Correlacion cruzada en rotación:  -3.2489999999999997   [7.476804e+08]
# Correlacion cruzada en rotación:  -3.246   [7.476778e+08]
# Correlacion cruzada en rotación:  -3.243   [7.476776e+08]
# Correlacion cruzada en rotación:  -3.2399999999999998   [7.476793e+08]
# La tercera rotación es:  [-3.291]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f33d61f9bd0>,
#  <matplotlib.image.AxesImage at 0x7f33d6106490>,
#  Text(0.5, 1.0, 'Registro Completo'))

# %% [markdown]
# Resultados en BGR

# %%
# Mostrando el resultado final en BGR #

presion_BGR= cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PresionPreProcesadaFinalIzq.JPG")
print(presion_BGR.shape)
(presion_B,presion_G,presion_R) = cv2.split(presion_BGR)

rows, cols, channels = presion_BGR.shape

M_escala = cv2.getRotationMatrix2D((cols/2,rows/2),0,s3)
M_traslacion_x = np.float32([[1,0,x3],[0,1,0]])
M_traslacion_y = np.float32([[1,0,0],[0,1,y3]])
M_rotacion = cv2.getRotationMatrix2D((cols/2,rows/2),r3,1)

presion_B = cv2.warpAffine(presion_B, M_escala, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_x, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_y, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_rotacion, (cols,rows))

presion_G = cv2.warpAffine(presion_G, M_escala, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_x, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_y, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_rotacion, (cols,rows))

presion_R = cv2.warpAffine(presion_R, M_escala, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_x, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_y, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_rotacion, (cols,rows))

presion_BGR_registro = cv2.merge([presion_B,presion_G,presion_R])

imagen1_RGB = cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
presion_RGB_registro = cv2.cvtColor(presion_BGR_registro, cv2.COLOR_BGR2RGB)

plt.figure(12)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')

#Mostrar la imagen fusionada
I_fusionada = cv2.addWeighted(imagen1,0.4,presion_BGR_registro,0.6,0)
cv2_imshow(I_fusionada)
# Out:
# (455, 455, 3)
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7F33D409D2D0>

# %% [markdown]
# Métricas de comparación

# %%
#Midiendo la información mutua final del registro
imagen1_RGB_gris = cv2.cvtColor(imagen1_RGB, cv2.COLOR_RGB2GRAY)
presion_RGB_registro_gris = cv2.cvtColor(presion_RGB_registro, cv2.COLOR_RGB2GRAY)

hist_2d, x_edges, y_edges = np.histogram2d(imagen1_RGB_gris.ravel(),presion_RGB_registro_gris.ravel(),bins=64)
    
# Calcular la información mutua entre las dos imágenes 
info_mutua_final = mutual_information(hist_2d)

#Midiendo la suma de diferencias al cuadrado
sqdiff = cv2.matchTemplate(imagen1_RGB_gris, presion_RGB_registro_gris, cv2.TM_SQDIFF)


plt.figure(13)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')

print("La información mutua es: ",info_mutua_final)
print("La sumatoria de diferencias al cuadrado es: ",sqdiff)
# Out:
# La información mutua es:  0.2587281361526146
# La sumatoria de diferencias al cuadrado es:  [[8.0325344e+08]]

# %% [markdown]
# Salida de imagen

# %%
Salida_registro = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_CCORR.JPG",imagen2_sxyr3)
Salida_registro_BGR = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_BGR_CCORR.JPG",presion_BGR_registro)
