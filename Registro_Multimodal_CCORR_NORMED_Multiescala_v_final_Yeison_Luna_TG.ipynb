# %% [markdown]
# <a href="https://colab.research.google.com/github/yeisonluna/RegistroMultimodal/blob/main/Registro_Multimodal_CCORR_NORMED_Multiescala_v_final_Yeison_Luna_TG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGISTRO MULTIMODAL DE IMÁGENES CON CORRELACION CRUZADA NORMALIZADA - BÚSQUEDA MULTIESCALA**
#
#
#
# ---

# %% [markdown]
# Importación de Bibliotecas

# %%
import numpy as np  #paquete de arreglos
import matplotlib as pyplot 
import matplotlib.pyplot as plt  # paquete de gráficos
import cv2 
from google.colab.patches import cv2_imshow # para imprimir imágenes

# %% [markdown]
# Se importan las imágenes, guardadas en un drive de google.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importación de Imágenes

# %%
plt.style.use('ggplot')
#imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/img358.tif")
#imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Paciente_1010244758_Presion-Promedio_2a_Pre_Procesada_2.TIFF")
imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Podoscopio_preprocesada_total.JPG")
imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift.TIFF")

# %% [markdown]
# # Funciones del algoritmo

# %% [markdown]
# Funcion multiescala

# %%
def scale_img_1(im1, im2):
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    escala_max = 1

# ----------------------------------- Ciclo 1 -------------------------------- #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = escala_max/n_int
        b1 = 0.2
        f = float(m1*i+b1)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,f)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]
            
        NCC_1.append(ncc)
        print("Correlacion normalizada cruzada en escala: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    scale = np.where(NCC_1==max(NCC_1))
    escala = scale[0]
    
    print("La primera escala es: ",m1*escala+b1)

    funcion_final = float(m1*escala)
    

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala 

def scale_img_2(im1,im2,escala):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]
    escala_max = 1

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
        

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*escala_max/(n_int**2)
        b2 = 0.2 + escala_max*(escala-1)/n_int 
        g = float(m2*j+b2)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,g)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en escala: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    scale_2 = np.where(NCC_2==max(NCC_2))
    escala_2 = scale_2[0]
    
    print("La segunda escala es: ",m2*escala_2+b2)

    funcion_final = float(m2*escala_2+b2)    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala_2
    

def scale_img_3(im1,im2,escala,escala_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    escala_max = 1


    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)


        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 4*escala_max/(n_int**3)
        b3 = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
        h = float(m3*k+b3)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,h)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en escala: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    scale_3 = np.where(NCC_3==max(NCC_3))
    escala_3 = scale_3[0]
    
    print("La tercera escala es: ",m3*escala_3+b3)
    
    m_final = 4*escala_max/(n_int**3)
    b_final = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
    funcion_final = float(m_final*escala_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funciones de traslacion

# %%
def shift_img_x_1(im1, im2):
    
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    
    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*cols/n_int   
        b1 = 0-cols
        f = (m1*i + b1)
            
        shift_matrix_x_axis = np.float32([[1,0,f],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_x = np.where(NCC_1==max(NCC_1))
    traslacion_x = shift_x[0]
    
    print("La primera traslacion es: ",m1*traslacion_x+b1)

    funcion_final = (m1*traslacion_x+b1) 
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x

def shift_img_x_2(im1, im2, traslacion_x):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]

    for j in range (n_int+1): 
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2 

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*cols)/(n_int**2)
        b2 = (2*cols*(traslacion_x-1))/n_int - (cols)
        g = (m2*j+b2)
                
        shift_matrix_x_axis = np.float32([[1,0,g],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_x_2 = np.where(NCC_2==max(NCC_2))
    traslacion_x_2 = shift_x_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_x_2+b2)

    funcion_final = (m2*traslacion_x_2+b2)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x_2

def shift_img_x_3(im1,im2,traslacion_x,traslacion_x_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*cols)/(n_int**3)
        b3 = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
        h = (m3*k+b3)
                
        shift_matrix_x_axis = np.float32([[1,0,h],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_x_3 = np.where(NCC_3==max(NCC_3))
    traslacion_x_3 = shift_x_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_x_3+b3)
    

    m_final = 2*(4*cols)/(n_int**3)
    b_final = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
    funcion_final = (m_final*traslacion_x_3+b_final)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de traslación en y

# %%
def shift_img_y_1(im1, im2):   
   
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 

    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*rows/n_int   
        b1 = 0-rows
        f = (m1*i + b1)
            
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,f]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_y = np.where(NCC_1==max(NCC_1))
    traslacion_y = shift_y[0]
    
    print("La primera traslacion es: ",m1*traslacion_y+b1)

    funcion_final = (m1*traslacion_y + b1)    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y


def shift_img_y_2(im1,im2,traslacion_y):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]


    for j in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*rows)/(n_int**2)
        b2 = (2*rows*(traslacion_y-1))/n_int - (rows)
        g = (m2*j+b2)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,g]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            

            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_y_2 = np.where(NCC_2==max(NCC_2))
    traslacion_y_2 = shift_y_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_y_2+b2)

    funcion_final = (m2*traslacion_y_2+b2)     

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y_2

def shift_img_y_3(im1,im2,traslacion_y,traslacion_y_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*rows)/(n_int**3)
        b3 = 2*(2*rows)*(traslacion_y_2-1)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
        h = (m3*k+b3)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,h]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_y_3 = np.where(NCC_3==max(NCC_3))
    traslacion_y_3 = shift_y_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_y_3+b3)
    

    m_final = 2*(4*rows)/(n_int**3)
    b_final = 2*(2*rows)*(traslacion_y_2)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
    funcion_final = (m_final*traslacion_y_3+b_final)
    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de rotación

# %%
def rotation_matrix_1(im1, im2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1 = []
    angulo_max = 3

# ----------------------------------- Ciclo 1 ------------------------------------ #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*angulo_max/n_int
        b1 = 0-angulo_max
        f = float(m1*i+b1)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),f,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en rotacion: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    angle = np.where(NCC_1==max(NCC_1))
    angulo = angle[0]
    
    print("La primera rotación es: ",m1*angulo+b1)

    funcion_final = float(m1*angulo+b1)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo

def rotation_matrix_2(im1, im2, angulo):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2 = []
    angulo_max = 3

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*2*angulo_max/(n_int**2)
        b2 = 2*angulo_max*(angulo-1)/n_int - angulo_max
        g = float(m2*j+b2)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),g,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en rotación: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    angle_2 = np.where(NCC_2==max(NCC_2))
    angulo_2 = angle_2[0]
    
    print("La segunda rotación es: ",m2*angulo_2+b2)

    funcion_final = float(m2*angulo_2+b2)
     

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo_2

def rotation_matrix_3(im1, im2, angulo, angulo_2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    angulo_max = 3

    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*4*angulo_max/(n_int**3)
        b3 = 2*angulo_max*(angulo-1)/n_int + 2*2*angulo_max*(angulo_2-1)/(n_int**2) - angulo_max
        h = float(m3*k+b3)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),h,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en rotación: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    angle_3 = np.where(NCC_3==max(NCC_3))
    angulo_3 = angle_3[0]
    
    print("La tercera rotación es: ",m3*angulo_3+b3)
    
    m_final = 2*4*angulo_max/(n_int**3)
    b_final = angulo_max*(angulo-1)/n_int + 2*angulo_max*(angulo_2-1)/(n_int**2)
    funcion_final = float(m_final*angulo_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# # Resultados

# %%
#----------------------------------------------------------------------------------------#
#Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s1, s1 = scale_img_1(imagen1, imagen2)

plt.figure(0)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s1,'gray'),plt.title('S1')

imagen2_sx1, x1 = shift_img_x_1(imagen1, imagen2_s1)

plt.figure(1)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx1,'gray'),plt.title('S1, X1')

imagen2_sxy1, y1 = shift_img_y_1(imagen1, imagen2_sx1)

plt.figure(2)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy1,'gray'),plt.title('S1, X1, Y1')

imagen2_sxyr1, r1 = rotation_matrix_1(imagen1, imagen2_sxy1)

plt.figure(3)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr1,'gray'),plt.title('S1, X1, Y1, R1')

print("\n")

#----------------------------------------------------------------------------------------#
#Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
print("Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s2, s2 = scale_img_2(imagen1, imagen2, s1)

plt.figure(4)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s2,'gray'),plt.title('S2')

imagen2_sx2, x2 = shift_img_x_2(imagen1, imagen2_s2, x1)

plt.figure(5)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx2,'gray'),plt.title('S2, X2')

imagen2_sxy2, y2 = shift_img_y_2(imagen1, imagen2_sx2, y1)

plt.figure(6)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy2,'gray'),plt.title('S2, X2, Y2')


imagen2_sxyr2, r2 = rotation_matrix_2(imagen1, imagen2_sxy2, r1)

plt.figure(7)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr2,'gray'),plt.title('S2, X2, Y2, R2')

print("\n")

#----------------------------------------------------------------------------------------#
#Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s3, s3 = scale_img_3(imagen1, imagen2, s1, s2)

plt.figure(8)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s3,'gray'),plt.title('S3')

imagen2_sx3, x3 = shift_img_x_3(imagen1, imagen2_s3, x1, x2)

plt.figure(9)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx3,'gray'),plt.title('S3, X3')

imagen2_sxy3, y3 = shift_img_y_3(imagen1, imagen2_sx3, y1, y2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy3,'gray'),plt.title('S3, X3, Y3')


imagen2_sxyr3, r3 = rotation_matrix_3(imagen1, imagen2_sxy3, r1, r2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('S3, X3, Y3, R3')



#----------------------------------------------------------------------------------------#
# Mostrando el resultado final #


plt.figure(11)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('Original')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('Registro Completo')
# Out:
# Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion normalizada cruzada en escala:  0.2   [0.07697313]
# Correlacion normalizada cruzada en escala:  0.25   [0.10579437]
# Correlacion normalizada cruzada en escala:  0.30000000000000004   [0.13660008]
# Correlacion normalizada cruzada en escala:  0.35000000000000003   [0.16926517]
# Correlacion normalizada cruzada en escala:  0.4   [0.20433028]
# Correlacion normalizada cruzada en escala:  0.45   [0.24046698]
# Correlacion normalizada cruzada en escala:  0.5   [0.2771271]
# Correlacion normalizada cruzada en escala:  0.55   [0.31292185]
# Correlacion normalizada cruzada en escala:  0.6000000000000001   [0.34899172]
# Correlacion normalizada cruzada en escala:  0.65   [0.3845223]
# Correlacion normalizada cruzada en escala:  0.7   [0.41737542]
# Correlacion normalizada cruzada en escala:  0.75   [0.447169]
# Correlacion normalizada cruzada en escala:  0.8   [0.47602135]
# Correlacion normalizada cruzada en escala:  0.8500000000000001   [0.50743246]
# Correlacion normalizada cruzada en escala:  0.9000000000000001   [0.53899956]
# Correlacion normalizada cruzada en escala:  0.95   [0.5665206]
# Correlacion normalizada cruzada en escala:  1.0   [0.5837623]
# Correlacion normalizada cruzada en escala:  1.05   [0.5885962]
# Correlacion normalizada cruzada en escala:  1.1   [0.58004564]
# Correlacion normalizada cruzada en escala:  1.1500000000000001   [0.5660036]
# Correlacion normalizada cruzada en escala:  1.2   [0.5532192]
# La primera escala es:  [1.05]
# Correlacion cruzada normalizada en traslacion x:  -455.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  -409.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  -364.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  -318.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  -273.0   [0.00567451]
# Correlacion cruzada normalizada en traslacion x:  -227.5   [0.06144588]
# Correlacion cruzada normalizada en traslacion x:  -182.0   [0.09896107]
# Correlacion cruzada normalizada en traslacion x:  -136.5   [0.10168051]
# Correlacion cruzada normalizada en traslacion x:  -91.0   [0.10052848]
# Correlacion cruzada normalizada en traslacion x:  -45.5   [0.15116452]
# Correlacion cruzada normalizada en traslacion x:  0.0   [0.58842087]
# Correlacion cruzada normalizada en traslacion x:  45.5   [0.16679357]
# Correlacion cruzada normalizada en traslacion x:  91.0   [0.09945352]
# Correlacion cruzada normalizada en traslacion x:  136.5   [0.10445285]
# Correlacion cruzada normalizada en traslacion x:  182.0   [0.10323556]
# Correlacion cruzada normalizada en traslacion x:  227.5   [0.07800073]
# Correlacion cruzada normalizada en traslacion x:  273.0   [0.01847849]
# Correlacion cruzada normalizada en traslacion x:  318.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  364.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  409.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada normalizada en traslacion y:  -455.0   [0.]
# Correlacion cruzada normalizada en traslacion y:  -409.5   [0.]
# Correlacion cruzada normalizada en traslacion y:  -364.0   [0.]
# Correlacion cruzada normalizada en traslacion y:  -318.5   [0.00813194]
# Correlacion cruzada normalizada en traslacion y:  -273.0   [0.05441932]
# Correlacion cruzada normalizada en traslacion y:  -227.5   [0.07214503]
# Correlacion cruzada normalizada en traslacion y:  -182.0   [0.10149379]
# Correlacion cruzada normalizada en traslacion y:  -136.5   [0.16761927]
# Correlacion cruzada normalizada en traslacion y:  -91.0   [0.22796303]
# Correlacion cruzada normalizada en traslacion y:  -45.5   [0.3377742]
# Correlacion cruzada normalizada en traslacion y:  0.0   [0.58842087]
# Correlacion cruzada normalizada en traslacion y:  45.5   [0.30119172]
# Correlacion cruzada normalizada en traslacion y:  91.0   [0.18956175]
# Correlacion cruzada normalizada en traslacion y:  136.5   [0.12128154]
# Correlacion cruzada normalizada en traslacion y:  182.0   [0.07602676]
# Correlacion cruzada normalizada en traslacion y:  227.5   [0.05978424]
# Correlacion cruzada normalizada en traslacion y:  273.0   [0.0395327]
# Correlacion cruzada normalizada en traslacion y:  318.5   [0.0112536]
# Correlacion cruzada normalizada en traslacion y:  364.0   [0.]
# Correlacion cruzada normalizada en traslacion y:  409.5   [0.]
# Correlacion cruzada normalizada en traslacion y:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada normalizada en rotacion:  -3.0   [0.58597124]
# Correlacion cruzada normalizada en rotacion:  -2.7   [0.5868745]
# Correlacion cruzada normalizada en rotacion:  -2.4   [0.5876728]
# Correlacion cruzada normalizada en rotacion:  -2.1   [0.58831656]
# Correlacion cruzada normalizada en rotacion:  -1.8   [0.588772]
# Correlacion cruzada normalizada en rotacion:  -1.5   [0.5892161]
# Correlacion cruzada normalizada en rotacion:  -1.2000000000000002   [0.5895307]
# Correlacion cruzada normalizada en rotacion:  -0.8999999999999999   [0.5894971]
# Correlacion cruzada normalizada en rotacion:  -0.6000000000000001   [0.58955604]
# Correlacion cruzada normalizada en rotacion:  -0.30000000000000027   [0.5893198]
# Correlacion cruzada normalizada en rotacion:  0.0   [0.58842087]
# Correlacion cruzada normalizada en rotacion:  0.2999999999999998   [0.58854216]
# Correlacion cruzada normalizada en rotacion:  0.5999999999999996   [0.588064]
# Correlacion cruzada normalizada en rotacion:  0.8999999999999999   [0.5872955]
# Correlacion cruzada normalizada en rotacion:  1.2000000000000002   [0.58657455]
# Correlacion cruzada normalizada en rotacion:  1.5   [0.58553505]
# Correlacion cruzada normalizada en rotacion:  1.7999999999999998   [0.58441603]
# Correlacion cruzada normalizada en rotacion:  2.0999999999999996   [0.58335584]
# Correlacion cruzada normalizada en rotacion:  2.3999999999999995   [0.58209133]
# Correlacion cruzada normalizada en rotacion:  2.7   [0.58069223]
# Correlacion cruzada normalizada en rotacion:  3.0   [0.57923174]
# La primera rotación es:  [-0.6]
#
#
# Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada normalizada en escala:  1.0   [0.5837623]
# Correlacion cruzada normalizada en escala:  1.005   [0.58560556]
# Correlacion cruzada normalizada en escala:  1.01   [0.58675843]
# Correlacion cruzada normalizada en escala:  1.015   [0.5875076]
# Correlacion cruzada normalizada en escala:  1.02   [0.58806247]
# Correlacion cruzada normalizada en escala:  1.025   [0.58838403]
# Correlacion cruzada normalizada en escala:  1.03   [0.588703]
# Correlacion cruzada normalizada en escala:  1.035   [0.5889651]
# Correlacion cruzada normalizada en escala:  1.04   [0.5890782]
# Correlacion cruzada normalizada en escala:  1.045   [0.58889145]
# Correlacion cruzada normalizada en escala:  1.05   [0.5885962]
# Correlacion cruzada normalizada en escala:  1.055   [0.58816034]
# Correlacion cruzada normalizada en escala:  1.06   [0.5877617]
# Correlacion cruzada normalizada en escala:  1.065   [0.5872466]
# Correlacion cruzada normalizada en escala:  1.07   [0.58650225]
# Correlacion cruzada normalizada en escala:  1.075   [0.5856321]
# Correlacion cruzada normalizada en escala:  1.08   [0.58464986]
# Correlacion cruzada normalizada en escala:  1.085   [0.58363014]
# Correlacion cruzada normalizada en escala:  1.09   [0.5824612]
# Correlacion cruzada normalizada en escala:  1.095   [0.5812901]
# Correlacion cruzada normalizada en escala:  1.1   [0.58004564]
# La segunda escala es:  [1.04]
# Correlacion cruzada normalizada en traslacion x:  [-45.5]   [0.17684603]
# Correlacion cruzada normalizada en traslacion x:  [-40.95]   [0.20265564]
# Correlacion cruzada normalizada en traslacion x:  [-36.4]   [0.23538393]
# Correlacion cruzada normalizada en traslacion x:  [-31.85]   [0.27269515]
# Correlacion cruzada normalizada en traslacion x:  [-27.3]   [0.3141905]
# Correlacion cruzada normalizada en traslacion x:  [-22.75]   [0.35961038]
# Correlacion cruzada normalizada en traslacion x:  [-18.2]   [0.40734667]
# Correlacion cruzada normalizada en traslacion x:  [-13.65]   [0.457241]
# Correlacion cruzada normalizada en traslacion x:  [-9.1]   [0.50353235]
# Correlacion cruzada normalizada en traslacion x:  [-4.55]   [0.542634]
# Correlacion cruzada normalizada en traslacion x:  [0.]   [0.5684108]
# Correlacion cruzada normalizada en traslacion x:  [4.55]   [0.57880783]
# Correlacion cruzada normalizada en traslacion x:  [9.1]   [0.5701331]
# Correlacion cruzada normalizada en traslacion x:  [13.65]   [0.5417783]
# Correlacion cruzada normalizada en traslacion x:  [18.2]   [0.49935707]
# Correlacion cruzada normalizada en traslacion x:  [22.75]   [0.45346606]
# Correlacion cruzada normalizada en traslacion x:  [27.3]   [0.40599453]
# Correlacion cruzada normalizada en traslacion x:  [31.85]   [0.35673082]
# Correlacion cruzada normalizada en traslacion x:  [36.4]   [0.30655405]
# Correlacion cruzada normalizada en traslacion x:  [40.95]   [0.2575708]
# Correlacion cruzada normalizada en traslacion x:  [45.5]   [0.21440518]
# La segunda traslacion es:  [4.55]
# Correlacion cruzada normalizada en traslacion y:  [-45.5]   [0.3579278]
# Correlacion cruzada normalizada en traslacion y:  [-40.95]   [0.38736922]
# Correlacion cruzada normalizada en traslacion y:  [-36.4]   [0.41954085]
# Correlacion cruzada normalizada en traslacion y:  [-31.85]   [0.45191458]
# Correlacion cruzada normalizada en traslacion y:  [-27.3]   [0.4827799]
# Correlacion cruzada normalizada en traslacion y:  [-22.75]   [0.5088198]
# Correlacion cruzada normalizada en traslacion y:  [-18.2]   [0.53021663]
# Correlacion cruzada normalizada en traslacion y:  [-13.65]   [0.5492952]
# Correlacion cruzada normalizada en traslacion y:  [-9.1]   [0.56456226]
# Correlacion cruzada normalizada en traslacion y:  [-4.55]   [0.5747156]
# Correlacion cruzada normalizada en traslacion y:  [0.]   [0.57880783]
# Correlacion cruzada normalizada en traslacion y:  [4.55]   [0.57415015]
# Correlacion cruzada normalizada en traslacion y:  [9.1]   [0.55942637]
# Correlacion cruzada normalizada en traslacion y:  [13.65]   [0.5358946]
# Correlacion cruzada normalizada en traslacion y:  [18.2]   [0.5057685]
# Correlacion cruzada normalizada en traslacion y:  [22.75]   [0.47308752]
# Correlacion cruzada normalizada en traslacion y:  [27.3]   [0.4391682]
# Correlacion cruzada normalizada en traslacion y:  [31.85]   [0.40763044]
# Correlacion cruzada normalizada en traslacion y:  [36.4]   [0.37912145]
# Correlacion cruzada normalizada en traslacion y:  [40.95]   [0.35236055]
# Correlacion cruzada normalizada en traslacion y:  [45.5]   [0.32790163]
# La segunda traslacion es:  [0.]
# Correlacion cruzada normalizada en rotación:  -0.8999999999999999   [0.5800701]
# Correlacion cruzada normalizada en rotación:  -0.8699999999999999   [0.58004934]
# Correlacion cruzada normalizada en rotación:  -0.8399999999999999   [0.5800285]
# Correlacion cruzada normalizada en rotación:  -0.8099999999999999   [0.58000326]
# Correlacion cruzada normalizada en rotación:  -0.7799999999999999   [0.57997745]
# Correlacion cruzada normalizada en rotación:  -0.7499999999999999   [0.5799569]
# Correlacion cruzada normalizada en rotación:  -0.72   [0.5799373]
# Correlacion cruzada normalizada en rotación:  -0.69   [0.5799381]
# Correlacion cruzada normalizada en rotación:  -0.6599999999999999   [0.579921]
# Correlacion cruzada normalizada en rotación:  -0.6299999999999999   [0.579917]
# Correlacion cruzada normalizada en rotación:  -0.5999999999999999   [0.57991457]
# Correlacion cruzada normalizada en rotación:  -0.57   [0.57992053]
# Correlacion cruzada normalizada en rotación:  -0.5399999999999999   [0.57990843]
# Correlacion cruzada normalizada en rotación:  -0.5099999999999999   [0.57989186]
# Correlacion cruzada normalizada en rotación:  -0.4799999999999999   [0.57987297]
# Correlacion cruzada normalizada en rotación:  -0.44999999999999996   [0.579837]
# Correlacion cruzada normalizada en rotación:  -0.41999999999999993   [0.5798026]
# Correlacion cruzada normalizada en rotación:  -0.3899999999999999   [0.57978374]
# Correlacion cruzada normalizada en rotación:  -0.3599999999999999   [0.5797435]
# Correlacion cruzada normalizada en rotación:  -0.32999999999999996   [0.57971066]
# Correlacion cruzada normalizada en rotación:  -0.29999999999999993   [0.5796368]
# La segunda rotación es:  [-0.9]
#
#
# Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada normalizada en escala:  1.035   [0.5889651]
# Correlacion cruzada normalizada en escala:  1.0354999999999999   [0.5889651]
# Correlacion cruzada normalizada en escala:  1.0359999999999998   [0.588992]
# Correlacion cruzada normalizada en escala:  1.0365   [0.58900744]
# Correlacion cruzada normalizada en escala:  1.037   [0.5890062]
# Correlacion cruzada normalizada en escala:  1.0374999999999999   [0.5890324]
# Correlacion cruzada normalizada en escala:  1.0379999999999998   [0.58903015]
# Correlacion cruzada normalizada en escala:  1.0385   [0.58905536]
# Correlacion cruzada normalizada en escala:  1.039   [0.5890689]
# Correlacion cruzada normalizada en escala:  1.0394999999999999   [0.58904475]
# Correlacion cruzada normalizada en escala:  1.0399999999999998   [0.5890782]
# Correlacion cruzada normalizada en escala:  1.0405   [0.5890689]
# Correlacion cruzada normalizada en escala:  1.041   [0.58903503]
# Correlacion cruzada normalizada en escala:  1.0414999999999999   [0.58902407]
# Correlacion cruzada normalizada en escala:  1.0419999999999998   [0.589011]
# Correlacion cruzada normalizada en escala:  1.0425   [0.58901757]
# Correlacion cruzada normalizada en escala:  1.043   [0.588996]
# Correlacion cruzada normalizada en escala:  1.0434999999999999   [0.58896345]
# Correlacion cruzada normalizada en escala:  1.0439999999999998   [0.5889409]
# Correlacion cruzada normalizada en escala:  1.0445   [0.5889233]
# Correlacion cruzada normalizada en escala:  1.045   [0.58889145]
# La tercera escala es:  [1.04]
# Correlacion cruzada normalizada en traslacion x:  [0.]   [0.583884]
# Correlacion cruzada normalizada en traslacion x:  [0.455]   [0.58610994]
# Correlacion cruzada normalizada en traslacion x:  [0.91]   [0.58741295]
# Correlacion cruzada normalizada en traslacion x:  [1.365]   [0.58895546]
# Correlacion cruzada normalizada en traslacion x:  [1.82]   [0.58970445]
# Correlacion cruzada normalizada en traslacion x:  [2.275]   [0.59052837]
# Correlacion cruzada normalizada en traslacion x:  [2.73]   [0.590887]
# Correlacion cruzada normalizada en traslacion x:  [3.185]   [0.5910283]
# Correlacion cruzada normalizada en traslacion x:  [3.64]   [0.5911115]
# Correlacion cruzada normalizada en traslacion x:  [4.095]   [0.59045976]
# Correlacion cruzada normalizada en traslacion x:  [4.55]   [0.59016484]
# Correlacion cruzada normalizada en traslacion x:  [5.005]   [0.5889281]
# Correlacion cruzada normalizada en traslacion x:  [5.46]   [0.588283]
# Correlacion cruzada normalizada en traslacion x:  [5.915]   [0.58670354]
# Correlacion cruzada normalizada en traslacion x:  [6.37]   [0.58544165]
# Correlacion cruzada normalizada en traslacion x:  [6.825]   [0.5834887]
# Correlacion cruzada normalizada en traslacion x:  [7.28]   [0.581516]
# Correlacion cruzada normalizada en traslacion x:  [7.735]   [0.5792999]
# Correlacion cruzada normalizada en traslacion x:  [8.19]   [0.57675034]
# Correlacion cruzada normalizada en traslacion x:  [8.645]   [0.5740609]
# Correlacion cruzada normalizada en traslacion x:  [9.1]   [0.57112545]
# La tercera traslacion es:  [3.64]
# Correlacion cruzada normalizada en traslacion y:  [-4.55]   [0.5828278]
# Correlacion cruzada normalizada en traslacion y:  [-4.095]   [0.58429766]
# Correlacion cruzada normalizada en traslacion y:  [-3.64]   [0.5859336]
# Correlacion cruzada normalizada en traslacion y:  [-3.185]   [0.58703274]
# Correlacion cruzada normalizada en traslacion y:  [-2.73]   [0.5882476]
# Correlacion cruzada normalizada en traslacion y:  [-2.275]   [0.5890794]
# Correlacion cruzada normalizada en traslacion y:  [-1.82]   [0.58985436]
# Correlacion cruzada normalizada en traslacion y:  [-1.365]   [0.59062254]
# Correlacion cruzada normalizada en traslacion y:  [-0.91]   [0.59078974]
# Correlacion cruzada normalizada en traslacion y:  [-0.455]   [0.5913888]
# Correlacion cruzada normalizada en traslacion y:  [-1.15463195e-14]   [0.5911115]
# Correlacion cruzada normalizada en traslacion y:  [0.455]   [0.5913263]
# Correlacion cruzada normalizada en traslacion y:  [0.91]   [0.5910038]
# Correlacion cruzada normalizada en traslacion y:  [1.365]   [0.59086764]
# Correlacion cruzada normalizada en traslacion y:  [1.82]   [0.5902599]
# Correlacion cruzada normalizada en traslacion y:  [2.275]   [0.58964056]
# Correlacion cruzada normalizada en traslacion y:  [2.73]   [0.5888382]
# Correlacion cruzada normalizada en traslacion y:  [3.185]   [0.58780855]
# Correlacion cruzada normalizada en traslacion y:  [3.64]   [0.58692354]
# Correlacion cruzada normalizada en traslacion y:  [4.095]   [0.5854013]
# Correlacion cruzada normalizada en traslacion y:  [4.55]   [0.5841958]
# La tercera traslacion es:  [-0.455]
# Correlacion cruzada normalizada en rotación:  -0.9299999999999997   [0.58616334]
# Correlacion cruzada normalizada en rotación:  -0.9269999999999997   [0.58616585]
# Correlacion cruzada normalizada en rotación:  -0.9239999999999997   [0.58616245]
# Correlacion cruzada normalizada en rotación:  -0.9209999999999997   [0.58617]
# Correlacion cruzada normalizada en rotación:  -0.9179999999999997   [0.58617145]
# Correlacion cruzada normalizada en rotación:  -0.9149999999999997   [0.58616436]
# Correlacion cruzada normalizada en rotación:  -0.9119999999999997   [0.586167]
# Correlacion cruzada normalizada en rotación:  -0.9089999999999997   [0.5861807]
# Correlacion cruzada normalizada en rotación:  -0.9059999999999997   [0.58618516]
# Correlacion cruzada normalizada en rotación:  -0.9029999999999997   [0.58616346]
# Correlacion cruzada normalizada en rotación:  -0.8999999999999997   [0.58615863]
# Correlacion cruzada normalizada en rotación:  -0.8969999999999997   [0.58615565]
# Correlacion cruzada normalizada en rotación:  -0.8939999999999997   [0.5861448]
# Correlacion cruzada normalizada en rotación:  -0.8909999999999997   [0.5861385]
# Correlacion cruzada normalizada en rotación:  -0.8879999999999997   [0.5861699]
# Correlacion cruzada normalizada en rotación:  -0.8849999999999997   [0.58617455]
# Correlacion cruzada normalizada en rotación:  -0.8819999999999997   [0.5861682]
# Correlacion cruzada normalizada en rotación:  -0.8789999999999997   [0.5861589]
# Correlacion cruzada normalizada en rotación:  -0.8759999999999997   [0.5861595]
# Correlacion cruzada normalizada en rotación:  -0.8729999999999997   [0.5861597]
# Correlacion cruzada normalizada en rotación:  -0.8699999999999997   [0.5861573]
# La tercera rotación es:  [-0.906]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f170d4ad3d0>,
#  <matplotlib.image.AxesImage at 0x7f170cc145d0>,
#  Text(0.5, 1.0, 'Registro Completo'))

# %% [markdown]
# Resultados en BGR

# %%
# Mostrando el resultado final en BGR #

presion_BGR= cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift_BGR.JPG")
print(presion_BGR.shape)
(presion_B,presion_G,presion_R) = cv2.split(presion_BGR)

rows, cols, channels = presion_BGR.shape

M_escala = cv2.getRotationMatrix2D((cols/2,rows/2),0,s3)
M_traslacion_x = np.float32([[1,0,x3],[0,1,0]])
M_traslacion_y = np.float32([[1,0,0],[0,1,y3]])
M_rotacion = cv2.getRotationMatrix2D((cols/2,rows/2),r3,1)

presion_B = cv2.warpAffine(presion_B, M_escala, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_x, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_y, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_rotacion, (cols,rows))

presion_G = cv2.warpAffine(presion_G, M_escala, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_x, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_y, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_rotacion, (cols,rows))

presion_R = cv2.warpAffine(presion_R, M_escala, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_x, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_y, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_rotacion, (cols,rows))

presion_BGR_registro = cv2.merge([presion_B,presion_G,presion_R])

imagen1_RGB = cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
presion_RGB_registro = cv2.cvtColor(presion_BGR_registro, cv2.COLOR_BGR2RGB)

plt.figure(12)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')

cv2_imshow(imagen1)
cv2_imshow(presion_BGR_registro)
# Out:
# (455, 455, 3)
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7F170C69B110>
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7F170C69B2D0>

# %% [markdown]
# Salida de imagen

# %%
Salida_registro = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_CCORR_NORMED.JPG",imagen2_sxyr3)
Salida_registro_BGR = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_BGR_CCOR_NORMED.JPG",presion_BGR_registro)
