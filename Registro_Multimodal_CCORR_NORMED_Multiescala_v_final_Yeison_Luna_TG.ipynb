# %% [markdown]
# <a href="https://colab.research.google.com/github/yeisonluna/RegistroMultimodal/blob/main/Registro_Multimodal_CCORR_NORMED_Multiescala_v_final_Yeison_Luna_TG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGISTRO MULTIMODAL DE IMÁGENES CON CORRELACION CRUZADA NORMALIZADA - BÚSQUEDA MULTIESCALA**
#
#
#
# ---

# %% [markdown]
# Importación de Bibliotecas

# %%
import numpy as np  #paquete de arreglos
import matplotlib as pyplot 
import matplotlib.pyplot as plt  # paquete de gráficos
import cv2 
from google.colab.patches import cv2_imshow # para imprimir imágenes

# %% [markdown]
# Se importan las imágenes, guardadas en un drive de google.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importación de Imágenes

# %%
plt.style.use('ggplot')
imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PodoscopioPreProcesadaFinalIzq.JPG")
imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PresionPreProcesadaFinalIzq.JPG")
#imagen1 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Podoscopio_preprocesada_total.JPG")
#imagen2 = cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Presion_estimacion_escala_shift.TIFF")

# %% [markdown]
# # Funciones del algoritmo

# %% [markdown]
# Funcion multiescala

# %%
def scale_img_1(im1, im2):
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    escala_max = 1

# ----------------------------------- Ciclo 1 -------------------------------- #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = escala_max/n_int
        b1 = 0.2
        f = float(m1*i+b1)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,f)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]
            
        NCC_1.append(ncc)
        print("Correlacion normalizada cruzada en escala: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    scale = np.where(NCC_1==max(NCC_1))
    escala = scale[0]
    
    print("La primera escala es: ",m1*escala+b1)

    funcion_final = float(m1*escala)
    

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala 

def scale_img_2(im1,im2,escala):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]
    escala_max = 1

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
        

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*escala_max/(n_int**2)
        b2 = 0.2 + escala_max*(escala-1)/n_int 
        g = float(m2*j+b2)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,g)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))
        
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en escala: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    scale_2 = np.where(NCC_2==max(NCC_2))
    escala_2 = scale_2[0]
    
    print("La segunda escala es: ",m2*escala_2+b2)

    funcion_final = float(m2*escala_2+b2)    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))

    return dst, escala_2
    

def scale_img_3(im1,im2,escala,escala_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    escala_max = 1


    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)


        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 4*escala_max/(n_int**3)
        b3 = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
        h = float(m3*k+b3)
    
        escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,h)
        img2 = cv2.warpAffine(img2, escala_matrix, (cols,rows))

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en escala: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    scale_3 = np.where(NCC_3==max(NCC_3))
    escala_3 = scale_3[0]
    
    print("La tercera escala es: ",m3*escala_3+b3)
    
    m_final = 4*escala_max/(n_int**3)
    b_final = 0.2 + escala_max*(escala-1)/n_int + 2*escala_max*(escala_2-1)/(n_int**2)
    funcion_final = float(m_final*escala_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,funcion_final)
    dst = cv2.warpAffine(img2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funciones de traslacion

# %%
def shift_img_x_1(im1, im2):
    
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] #Arreglos de valores de info mutua
    
    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*cols/n_int   
        b1 = 0-cols
        f = (m1*i + b1)
            
        shift_matrix_x_axis = np.float32([[1,0,f],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_x = np.where(NCC_1==max(NCC_1))
    traslacion_x = shift_x[0]
    
    print("La primera traslacion es: ",m1*traslacion_x+b1)

    funcion_final = (m1*traslacion_x+b1) 
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x

def shift_img_x_2(im1, im2, traslacion_x):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]

    for j in range (n_int+1): 
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2 

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*cols)/(n_int**2)
        b2 = (2*cols*(traslacion_x-1))/n_int - (cols)
        g = (m2*j+b2)
                
        shift_matrix_x_axis = np.float32([[1,0,g],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_x_2 = np.where(NCC_2==max(NCC_2))
    traslacion_x_2 = shift_x_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_x_2+b2)

    funcion_final = (m2*traslacion_x_2+b2)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, traslacion_x_2

def shift_img_x_3(im1,im2,traslacion_x,traslacion_x_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2

        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*cols)/(n_int**3)
        b3 = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
        h = (m3*k+b3)
                
        shift_matrix_x_axis = np.float32([[1,0,h],[0,1,0]])
        img2 = cv2.warpAffine(img2, shift_matrix_x_axis, (cols,rows))
            

        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en traslacion x: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_x_3 = np.where(NCC_3==max(NCC_3))
    traslacion_x_3 = shift_x_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_x_3+b3)
    

    m_final = 2*(4*cols)/(n_int**3)
    b_final = 2*(2*cols)*(traslacion_x_2-1)/(n_int**2) + (2*cols*(traslacion_x-1))/n_int - (cols)
    funcion_final = (m_final*traslacion_x_3+b_final)
    
 

    shift_matrix_x_axis = np.float32([[1,0,funcion_final],[0,1,0]])
    dst = cv2.warpAffine(im2, shift_matrix_x_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de traslación en y

# %%
def shift_img_y_1(im1, im2):   
   
    
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1=[] 

    
 #--------------------------------- Ciclo 1 ------------------------------------------
    
    for i in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*rows/n_int   
        b1 = 0-rows
        f = (m1*i + b1)
            
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,f]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    shift_y = np.where(NCC_1==max(NCC_1))
    traslacion_y = shift_y[0]
    
    print("La primera traslacion es: ",m1*traslacion_y+b1)

    funcion_final = (m1*traslacion_y + b1)    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y


def shift_img_y_2(im1,im2,traslacion_y):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2=[]


    for j in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*(2*rows)/(n_int**2)
        b2 = (2*rows*(traslacion_y-1))/n_int - (rows)
        g = (m2*j+b2)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,g]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            

            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    shift_y_2 = np.where(NCC_2==max(NCC_2))
    traslacion_y_2 = shift_y_2[0]
    
    print("La segunda traslacion es: ",m2*traslacion_y_2+b2)

    funcion_final = (m2*traslacion_y_2+b2)     

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
    
    return dst, traslacion_y_2

def shift_img_y_3(im1,im2,traslacion_y,traslacion_y_2):

    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]


    for k in range (n_int+1): #Ciclo 1 (Se divide la imagen en intervalos de tamaño n_int)
        
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)  #Imagenes a blanco y negro
        img2 = im2
        
        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*(4*rows)/(n_int**3)
        b3 = 2*(2*rows)*(traslacion_y_2-1)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
        h = (m3*k+b3)
                
        shift_matrix_y_axis = np.float32([[1,0,0],[0,1,h]])
        img2 = cv2.warpAffine(img2, shift_matrix_y_axis, (cols,rows))
            
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en traslacion y: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    shift_y_3 = np.where(NCC_3==max(NCC_3))
    traslacion_y_3 = shift_y_3[0]
    
    print("La tercera traslacion es: ",m3*traslacion_y_3+b3)
    

    m_final = 2*(4*rows)/(n_int**3)
    b_final = 2*(2*rows)*(traslacion_y_2)/(n_int**2) + (2*rows*(traslacion_y-1))/n_int - (rows)
    funcion_final = (m_final*traslacion_y_3+b_final)
    
 

    shift_matrix_y_axis = np.float32([[1,0,0],[0,1,funcion_final]])
    dst = cv2.warpAffine(im2, shift_matrix_y_axis, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Función de rotación

# %%
def rotation_matrix_1(im1, im2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_1 = []
    angulo_max = 3

# ----------------------------------- Ciclo 1 ------------------------------------ #
    for i in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m1 = 2*angulo_max/n_int
        b1 = 0-angulo_max
        f = float(m1*i+b1)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),f,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_1.append(ncc)
        print("Correlacion cruzada normalizada en rotacion: ",f," ", ncc)


       
    
    NCC_1 = np.asarray(NCC_1)        
    angle = np.where(NCC_1==max(NCC_1))
    angulo = angle[0]
    
    print("La primera rotación es: ",m1*angulo+b1)

    funcion_final = float(m1*angulo+b1)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo

def rotation_matrix_2(im1, im2, angulo):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_2 = []
    angulo_max = 3

    for j in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m2 = 2*2*angulo_max/(n_int**2)
        b2 = 2*angulo_max*(angulo-1)/n_int - angulo_max
        g = float(m2*j+b2)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),g,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_2.append(ncc)
        print("Correlacion cruzada normalizada en rotación: ",g," ", ncc)


       
    
    NCC_2 = np.asarray(NCC_2)        
    angle_2 = np.where(NCC_2==max(NCC_2))
    angulo_2 = angle_2[0]
    
    print("La segunda rotación es: ",m2*angulo_2+b2)

    funcion_final = float(m2*angulo_2+b2)
     

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, angulo_2

def rotation_matrix_3(im1, im2, angulo, angulo_2):
        
    n_int = 20   #Numero de Intervalos de busqueda multiescala
    NCC_3=[]
    angulo_max = 3

    for k in range (n_int+1):
        
        img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY) 
        img2 = im2

        #Obtener el tamaño de la imagen
        rows, cols = img1.shape[:2]
        
        m3 = 2*4*angulo_max/(n_int**3)
        b3 = 2*angulo_max*(angulo-1)/n_int + 2*2*angulo_max*(angulo_2-1)/(n_int**2) - angulo_max
        h = float(m3*k+b3)
    
        angulo_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),h,1)
        img2 = cv2.warpAffine(img2, angulo_matrix, (cols,rows))
        
            
        # Calcular la NCC entre las dos imágenes 
        normxcorr = cv2.matchTemplate(img1, img2, cv2.TM_CCORR_NORMED)
        ncc = normxcorr[0]

            
        NCC_3.append(ncc)
        print("Correlacion cruzada normalizada en rotación: ",h," ", ncc)


       
    
    NCC_3 = np.asarray(NCC_3)        
    angle_3 = np.where(NCC_3==max(NCC_3))
    angulo_3 = angle_3[0]
    
    print("La tercera rotación es: ",m3*angulo_3+b3)
    
    m_final = 2*4*angulo_max/(n_int**3)
    b_final = angulo_max*(angulo-1)/n_int + 2*angulo_max*(angulo_2-1)/(n_int**2)
    funcion_final = float(m_final*angulo_3+b_final)
    
 

    escala_matrix = cv2.getRotationMatrix2D((cols/2,rows/2),funcion_final,1)
    dst = cv2.warpAffine(im2, escala_matrix, (cols,rows))
            
    
    return dst, funcion_final

# %% [markdown]
# Funcion de información mutua

# %%
def mutual_information(hgram):
   # Convertir los recuentos de los rangos en valores de probabilidad
    pxy = hgram / float(np.sum(hgram))
    px = np.sum(pxy, axis=1) # marginal para x sobre y
    py = np.sum(pxy, axis=0) # marginal para y sobre x
    px_py = px[:, None] * py[None, :] # multiplicar probabilidades 
    # Ahora podemos hacer el cálculo usando las matrices 2D pxy, px_py
    nzs = pxy > 0 # Solo valores no nulos en la suma
    return np.sum(pxy[nzs] * np.log(pxy[nzs] / px_py[nzs]))

# %% [markdown]
# # Resultados

# %%
#----------------------------------------------------------------------------------------#
#Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s1, s1 = scale_img_1(imagen1, imagen2)

plt.figure(0)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s1,'gray'),plt.title('S1')

imagen2_sx1, x1 = shift_img_x_1(imagen1, imagen2_s1)

plt.figure(1)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx1,'gray'),plt.title('S1, X1')

imagen2_sxy1, y1 = shift_img_y_1(imagen1, imagen2_sx1)

plt.figure(2)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy1,'gray'),plt.title('S1, X1, Y1')

imagen2_sxyr1, r1 = rotation_matrix_1(imagen1, imagen2_sxy1)

plt.figure(3)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr1,'gray'),plt.title('S1, X1, Y1, R1')

print("\n")

#----------------------------------------------------------------------------------------#
#Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
print("Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s2, s2 = scale_img_2(imagen1, imagen2, s1)

plt.figure(4)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s2,'gray'),plt.title('S2')

imagen2_sx2, x2 = shift_img_x_2(imagen1, imagen2_s2, x1)

plt.figure(5)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx2,'gray'),plt.title('S2, X2')

imagen2_sxy2, y2 = shift_img_y_2(imagen1, imagen2_sx2, y1)

plt.figure(6)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy2,'gray'),plt.title('S2, X2, Y2')


imagen2_sxyr2, r2 = rotation_matrix_2(imagen1, imagen2_sxy2, r1)

plt.figure(7)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr2,'gray'),plt.title('S2, X2, Y2, R2')

print("\n")

#----------------------------------------------------------------------------------------#
#Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:

print("Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación: \n")

imagen2_s3, s3 = scale_img_3(imagen1, imagen2, s1, s2)

plt.figure(8)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_s3,'gray'),plt.title('S3')

imagen2_sx3, x3 = shift_img_x_3(imagen1, imagen2_s3, x1, x2)

plt.figure(9)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sx3,'gray'),plt.title('S3, X3')

imagen2_sxy3, y3 = shift_img_y_3(imagen1, imagen2_sx3, y1, y2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxy3,'gray'),plt.title('S3, X3, Y3')


imagen2_sxyr3, r3 = rotation_matrix_3(imagen1, imagen2_sxy3, r1, r2)

plt.figure(10)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('ORIGINAL')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('S3, X3, Y3, R3')



#----------------------------------------------------------------------------------------#
# Mostrando el resultado final #


plt.figure(11)
plt.subplot(121),plt.imshow(imagen1,'gray'),plt.title('Original')
plt.subplot(122),plt.imshow(imagen2_sxyr3,'gray'),plt.title('Registro Completo')
# Out:
# Primera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion normalizada cruzada en escala:  0.2   [0.10387716]
# Correlacion normalizada cruzada en escala:  0.25   [0.1409197]
# Correlacion normalizada cruzada en escala:  0.30000000000000004   [0.1806918]
# Correlacion normalizada cruzada en escala:  0.35000000000000003   [0.22346017]
# Correlacion normalizada cruzada en escala:  0.4   [0.26792538]
# Correlacion normalizada cruzada en escala:  0.45   [0.3130903]
# Correlacion normalizada cruzada en escala:  0.5   [0.35905394]
# Correlacion normalizada cruzada en escala:  0.55   [0.40458527]
# Correlacion normalizada cruzada en escala:  0.6000000000000001   [0.4501869]
# Correlacion normalizada cruzada en escala:  0.65   [0.4949111]
# Correlacion normalizada cruzada en escala:  0.7   [0.5381755]
# Correlacion normalizada cruzada en escala:  0.75   [0.57913846]
# Correlacion normalizada cruzada en escala:  0.8   [0.61530113]
# Correlacion normalizada cruzada en escala:  0.8500000000000001   [0.6470098]
# Correlacion normalizada cruzada en escala:  0.9000000000000001   [0.67664176]
# Correlacion normalizada cruzada en escala:  0.95   [0.70323515]
# Correlacion normalizada cruzada en escala:  1.0   [0.7240318]
# Correlacion normalizada cruzada en escala:  1.05   [0.73464453]
# Correlacion normalizada cruzada en escala:  1.1   [0.7322564]
# Correlacion normalizada cruzada en escala:  1.1500000000000001   [0.72173595]
# Correlacion normalizada cruzada en escala:  1.2   [0.7070106]
# La primera escala es:  [1.05]
# Correlacion cruzada normalizada en traslacion x:  -455.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  -409.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  -364.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  -318.5   [0.01742902]
# Correlacion cruzada normalizada en traslacion x:  -273.0   [0.05098067]
# Correlacion cruzada normalizada en traslacion x:  -227.5   [0.08202088]
# Correlacion cruzada normalizada en traslacion x:  -182.0   [0.11456462]
# Correlacion cruzada normalizada en traslacion x:  -136.5   [0.13744773]
# Correlacion cruzada normalizada en traslacion x:  -91.0   [0.1695275]
# Correlacion cruzada normalizada en traslacion x:  -45.5   [0.40496156]
# Correlacion cruzada normalizada en traslacion x:  0.0   [0.73026514]
# Correlacion cruzada normalizada en traslacion x:  45.5   [0.55181587]
# Correlacion cruzada normalizada en traslacion x:  91.0   [0.21326463]
# Correlacion cruzada normalizada en traslacion x:  136.5   [0.11470973]
# Correlacion cruzada normalizada en traslacion x:  182.0   [0.11223659]
# Correlacion cruzada normalizada en traslacion x:  227.5   [0.09675584]
# Correlacion cruzada normalizada en traslacion x:  273.0   [0.06607104]
# Correlacion cruzada normalizada en traslacion x:  318.5   [0.02530156]
# Correlacion cruzada normalizada en traslacion x:  364.0   [0.]
# Correlacion cruzada normalizada en traslacion x:  409.5   [0.]
# Correlacion cruzada normalizada en traslacion x:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada normalizada en traslacion y:  -455.0   [0.]
# Correlacion cruzada normalizada en traslacion y:  -409.5   [0.01651754]
# Correlacion cruzada normalizada en traslacion y:  -364.0   [0.05991633]
# Correlacion cruzada normalizada en traslacion y:  -318.5   [0.12434418]
# Correlacion cruzada normalizada en traslacion y:  -273.0   [0.20230147]
# Correlacion cruzada normalizada en traslacion y:  -227.5   [0.27839866]
# Correlacion cruzada normalizada en traslacion y:  -182.0   [0.317709]
# Correlacion cruzada normalizada en traslacion y:  -136.5   [0.34404972]
# Correlacion cruzada normalizada en traslacion y:  -91.0   [0.47392225]
# Correlacion cruzada normalizada en traslacion y:  -45.5   [0.6482542]
# Correlacion cruzada normalizada en traslacion y:  0.0   [0.73026514]
# Correlacion cruzada normalizada en traslacion y:  45.5   [0.5366489]
# Correlacion cruzada normalizada en traslacion y:  91.0   [0.35540888]
# Correlacion cruzada normalizada en traslacion y:  136.5   [0.29824826]
# Correlacion cruzada normalizada en traslacion y:  182.0   [0.22081913]
# Correlacion cruzada normalizada en traslacion y:  227.5   [0.17450638]
# Correlacion cruzada normalizada en traslacion y:  273.0   [0.10940544]
# Correlacion cruzada normalizada en traslacion y:  318.5   [0.08484534]
# Correlacion cruzada normalizada en traslacion y:  364.0   [0.04122587]
# Correlacion cruzada normalizada en traslacion y:  409.5   [0.00454328]
# Correlacion cruzada normalizada en traslacion y:  455.0   [0.]
# La primera traslacion es:  [0.]
# Correlacion cruzada normalizada en rotacion:  -3.0   [0.71904814]
# Correlacion cruzada normalizada en rotacion:  -2.7   [0.7205441]
# Correlacion cruzada normalizada en rotacion:  -2.4   [0.7219913]
# Correlacion cruzada normalizada en rotacion:  -2.1   [0.7233806]
# Correlacion cruzada normalizada en rotacion:  -1.8   [0.7246603]
# Correlacion cruzada normalizada en rotacion:  -1.5   [0.72588575]
# Correlacion cruzada normalizada en rotacion:  -1.2000000000000002   [0.727021]
# Correlacion cruzada normalizada en rotacion:  -0.8999999999999999   [0.72806835]
# Correlacion cruzada normalizada en rotacion:  -0.6000000000000001   [0.7290197]
# Correlacion cruzada normalizada en rotacion:  -0.30000000000000027   [0.7298765]
# Correlacion cruzada normalizada en rotacion:  0.0   [0.73026514]
# Correlacion cruzada normalizada en rotacion:  0.2999999999999998   [0.73111635]
# Correlacion cruzada normalizada en rotacion:  0.5999999999999996   [0.7316415]
# Correlacion cruzada normalizada en rotacion:  0.8999999999999999   [0.7319399]
# Correlacion cruzada normalizada en rotacion:  1.2000000000000002   [0.73218936]
# Correlacion cruzada normalizada en rotacion:  1.5   [0.73231953]
# Correlacion cruzada normalizada en rotacion:  1.7999999999999998   [0.7322927]
# Correlacion cruzada normalizada en rotacion:  2.0999999999999996   [0.732178]
# Correlacion cruzada normalizada en rotacion:  2.3999999999999995   [0.73190665]
# Correlacion cruzada normalizada en rotacion:  2.7   [0.73152995]
# Correlacion cruzada normalizada en rotacion:  3.0   [0.7310291]
# La primera rotación es:  [1.5]
#
#
# Segunda variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada normalizada en escala:  1.0   [0.7240318]
# Correlacion cruzada normalizada en escala:  1.005   [0.7260397]
# Correlacion cruzada normalizada en escala:  1.01   [0.7274064]
# Correlacion cruzada normalizada en escala:  1.015   [0.7287268]
# Correlacion cruzada normalizada en escala:  1.02   [0.7299965]
# Correlacion cruzada normalizada en escala:  1.025   [0.7310919]
# Correlacion cruzada normalizada en escala:  1.03   [0.73204654]
# Correlacion cruzada normalizada en escala:  1.035   [0.7329266]
# Correlacion cruzada normalizada en escala:  1.04   [0.73361075]
# Correlacion cruzada normalizada en escala:  1.045   [0.7341907]
# Correlacion cruzada normalizada en escala:  1.05   [0.73464453]
# Correlacion cruzada normalizada en escala:  1.055   [0.73494655]
# Correlacion cruzada normalizada en escala:  1.06   [0.7351501]
# Correlacion cruzada normalizada en escala:  1.065   [0.7351682]
# Correlacion cruzada normalizada en escala:  1.07   [0.7350561]
# Correlacion cruzada normalizada en escala:  1.075   [0.7348744]
# Correlacion cruzada normalizada en escala:  1.08   [0.73450845]
# Correlacion cruzada normalizada en escala:  1.085   [0.73415035]
# Correlacion cruzada normalizada en escala:  1.09   [0.7335996]
# Correlacion cruzada normalizada en escala:  1.095   [0.7329512]
# Correlacion cruzada normalizada en escala:  1.1   [0.7322564]
# La segunda escala es:  [1.065]
# Correlacion cruzada normalizada en traslacion x:  [-45.5]   [0.42008245]
# Correlacion cruzada normalizada en traslacion x:  [-40.95]   [0.4508849]
# Correlacion cruzada normalizada en traslacion x:  [-36.4]   [0.4828428]
# Correlacion cruzada normalizada en traslacion x:  [-31.85]   [0.5146189]
# Correlacion cruzada normalizada en traslacion x:  [-27.3]   [0.54661834]
# Correlacion cruzada normalizada en traslacion x:  [-22.75]   [0.5783215]
# Correlacion cruzada normalizada en traslacion x:  [-18.2]   [0.6085605]
# Correlacion cruzada normalizada en traslacion x:  [-13.65]   [0.6376146]
# Correlacion cruzada normalizada en traslacion x:  [-9.1]   [0.66604054]
# Correlacion cruzada normalizada en traslacion x:  [-4.55]   [0.69222873]
# Correlacion cruzada normalizada en traslacion x:  [0.]   [0.71598935]
# Correlacion cruzada normalizada en traslacion x:  [4.55]   [0.7359476]
# Correlacion cruzada normalizada en traslacion x:  [9.1]   [0.7502027]
# Correlacion cruzada normalizada en traslacion x:  [13.65]   [0.7590479]
# Correlacion cruzada normalizada en traslacion x:  [18.2]   [0.76068544]
# Correlacion cruzada normalizada en traslacion x:  [22.75]   [0.75493723]
# Correlacion cruzada normalizada en traslacion x:  [27.3]   [0.74083316]
# Correlacion cruzada normalizada en traslacion x:  [31.85]   [0.71929175]
# Correlacion cruzada normalizada en traslacion x:  [36.4]   [0.6925096]
# Correlacion cruzada normalizada en traslacion x:  [40.95]   [0.66213924]
# Correlacion cruzada normalizada en traslacion x:  [45.5]   [0.63140315]
# La segunda traslacion es:  [18.2]
# Correlacion cruzada normalizada en traslacion y:  [-45.5]   [0.682971]
# Correlacion cruzada normalizada en traslacion y:  [-40.95]   [0.69801176]
# Correlacion cruzada normalizada en traslacion y:  [-36.4]   [0.7142804]
# Correlacion cruzada normalizada en traslacion y:  [-31.85]   [0.729649]
# Correlacion cruzada normalizada en traslacion y:  [-27.3]   [0.74443465]
# Correlacion cruzada normalizada en traslacion y:  [-22.75]   [0.7572374]
# Correlacion cruzada normalizada en traslacion y:  [-18.2]   [0.7666619]
# Correlacion cruzada normalizada en traslacion y:  [-13.65]   [0.77187973]
# Correlacion cruzada normalizada en traslacion y:  [-9.1]   [0.77277696]
# Correlacion cruzada normalizada en traslacion y:  [-4.55]   [0.76909775]
# Correlacion cruzada normalizada en traslacion y:  [0.]   [0.76068544]
# Correlacion cruzada normalizada en traslacion y:  [4.55]   [0.7479823]
# Correlacion cruzada normalizada en traslacion y:  [9.1]   [0.731965]
# Correlacion cruzada normalizada en traslacion y:  [13.65]   [0.7132915]
# Correlacion cruzada normalizada en traslacion y:  [18.2]   [0.6932682]
# Correlacion cruzada normalizada en traslacion y:  [22.75]   [0.6720958]
# Correlacion cruzada normalizada en traslacion y:  [27.3]   [0.65084565]
# Correlacion cruzada normalizada en traslacion y:  [31.85]   [0.63061696]
# Correlacion cruzada normalizada en traslacion y:  [36.4]   [0.6113688]
# Correlacion cruzada normalizada en traslacion y:  [40.95]   [0.59302413]
# Correlacion cruzada normalizada en traslacion y:  [45.5]   [0.5769255]
# La segunda traslacion es:  [-9.1]
# Correlacion cruzada normalizada en rotación:  1.2000000000000002   [0.76737857]
# Correlacion cruzada normalizada en rotación:  1.2300000000000002   [0.76719576]
# Correlacion cruzada normalizada en rotación:  1.2600000000000002   [0.76703346]
# Correlacion cruzada normalizada en rotación:  1.2900000000000003   [0.76687396]
# Correlacion cruzada normalizada en rotación:  1.3200000000000003   [0.76671576]
# Correlacion cruzada normalizada en rotación:  1.35   [0.7665379]
# Correlacion cruzada normalizada en rotación:  1.3800000000000001   [0.76638323]
# Correlacion cruzada normalizada en rotación:  1.4100000000000001   [0.7662174]
# Correlacion cruzada normalizada en rotación:  1.4400000000000002   [0.7660557]
# Correlacion cruzada normalizada en rotación:  1.4700000000000002   [0.76588815]
# Correlacion cruzada normalizada en rotación:  1.5000000000000002   [0.7657217]
# Correlacion cruzada normalizada en rotación:  1.5300000000000002   [0.765533]
# Correlacion cruzada normalizada en rotación:  1.56   [0.7653533]
# Correlacion cruzada normalizada en rotación:  1.5900000000000003   [0.7651845]
# Correlacion cruzada normalizada en rotación:  1.62   [0.7650025]
# Correlacion cruzada normalizada en rotación:  1.6500000000000001   [0.76483035]
# Correlacion cruzada normalizada en rotación:  1.6800000000000002   [0.7646481]
# Correlacion cruzada normalizada en rotación:  1.7100000000000002   [0.7644727]
# Correlacion cruzada normalizada en rotación:  1.7400000000000002   [0.76430374]
# Correlacion cruzada normalizada en rotación:  1.77   [0.76414275]
# Correlacion cruzada normalizada en rotación:  1.8000000000000003   [0.7639643]
# La segunda rotación es:  [1.2]
#
#
# Tercera variación de parámetros en orden: escala, traslación x, traslación y, rotación:
#
# Correlacion cruzada normalizada en escala:  1.06   [0.7351501]
# Correlacion cruzada normalizada en escala:  1.0605   [0.7351541]
# Correlacion cruzada normalizada en escala:  1.061   [0.73513937]
# Correlacion cruzada normalizada en escala:  1.0615   [0.73515016]
# Correlacion cruzada normalizada en escala:  1.062   [0.7351545]
# Correlacion cruzada normalizada en escala:  1.0625   [0.7351693]
# Correlacion cruzada normalizada en escala:  1.063   [0.73519045]
# Correlacion cruzada normalizada en escala:  1.0635000000000001   [0.73518413]
# Correlacion cruzada normalizada en escala:  1.064   [0.7351682]
# Correlacion cruzada normalizada en escala:  1.0645   [0.7351637]
# Correlacion cruzada normalizada en escala:  1.065   [0.7351682]
# Correlacion cruzada normalizada en escala:  1.0655000000000001   [0.7351613]
# Correlacion cruzada normalizada en escala:  1.066   [0.73515874]
# Correlacion cruzada normalizada en escala:  1.0665   [0.73515326]
# Correlacion cruzada normalizada en escala:  1.067   [0.7351568]
# Correlacion cruzada normalizada en escala:  1.0675000000000001   [0.73515725]
# Correlacion cruzada normalizada en escala:  1.068   [0.73509187]
# Correlacion cruzada normalizada en escala:  1.0685   [0.7350799]
# Correlacion cruzada normalizada en escala:  1.069   [0.73508704]
# Correlacion cruzada normalizada en escala:  1.0695000000000001   [0.73504895]
# Correlacion cruzada normalizada en escala:  1.07   [0.7350561]
# La tercera escala es:  [1.063]
# Correlacion cruzada normalizada en traslacion x:  [13.65]   [0.76341695]
# Correlacion cruzada normalizada en traslacion x:  [14.105]   [0.76342666]
# Correlacion cruzada normalizada en traslacion x:  [14.56]   [0.7637507]
# Correlacion cruzada normalizada en traslacion x:  [15.015]   [0.76356953]
# Correlacion cruzada normalizada en traslacion x:  [15.47]   [0.7636375]
# Correlacion cruzada normalizada en traslacion x:  [15.925]   [0.76349443]
# Correlacion cruzada normalizada en traslacion x:  [16.38]   [0.7633878]
# Correlacion cruzada normalizada en traslacion x:  [16.835]   [0.7630545]
# Correlacion cruzada normalizada en traslacion x:  [17.29]   [0.76273054]
# Correlacion cruzada normalizada en traslacion x:  [17.745]   [0.7623655]
# Correlacion cruzada normalizada en traslacion x:  [18.2]   [0.7616391]
# Correlacion cruzada normalizada en traslacion x:  [18.655]   [0.76104665]
# Correlacion cruzada normalizada en traslacion x:  [19.11]   [0.7603086]
# Correlacion cruzada normalizada en traslacion x:  [19.565]   [0.759597]
# Correlacion cruzada normalizada en traslacion x:  [20.02]   [0.75862974]
# Correlacion cruzada normalizada en traslacion x:  [20.475]   [0.75785875]
# Correlacion cruzada normalizada en traslacion x:  [20.93]   [0.7566285]
# Correlacion cruzada normalizada en traslacion x:  [21.385]   [0.7557586]
# Correlacion cruzada normalizada en traslacion x:  [21.84]   [0.75438523]
# Correlacion cruzada normalizada en traslacion x:  [22.295]   [0.753265]
# Correlacion cruzada normalizada en traslacion x:  [22.75]   [0.7519839]
# La tercera traslacion es:  [14.56]
# Correlacion cruzada normalizada en traslacion y:  [-13.65]   [0.7799899]
# Correlacion cruzada normalizada en traslacion y:  [-13.195]   [0.7802815]
# Correlacion cruzada normalizada en traslacion y:  [-12.74]   [0.7806021]
# Correlacion cruzada normalizada en traslacion y:  [-12.285]   [0.7806314]
# Correlacion cruzada normalizada en traslacion y:  [-11.83]   [0.7806363]
# Correlacion cruzada normalizada en traslacion y:  [-11.375]   [0.7808264]
# Correlacion cruzada normalizada en traslacion y:  [-10.92]   [0.7806289]
# Correlacion cruzada normalizada en traslacion y:  [-10.465]   [0.7807425]
# Correlacion cruzada normalizada en traslacion y:  [-10.01]   [0.7804455]
# Correlacion cruzada normalizada en traslacion y:  [-9.555]   [0.7803749]
# Correlacion cruzada normalizada en traslacion y:  [-9.1]   [0.78010505]
# Correlacion cruzada normalizada en traslacion y:  [-8.645]   [0.7798748]
# Correlacion cruzada normalizada en traslacion y:  [-8.19]   [0.7795019]
# Correlacion cruzada normalizada en traslacion y:  [-7.735]   [0.7793051]
# Correlacion cruzada normalizada en traslacion y:  [-7.28]   [0.778697]
# Correlacion cruzada normalizada en traslacion y:  [-6.825]   [0.7781364]
# Correlacion cruzada normalizada en traslacion y:  [-6.37]   [0.77766246]
# Correlacion cruzada normalizada en traslacion y:  [-5.915]   [0.7769096]
# Correlacion cruzada normalizada en traslacion y:  [-5.46]   [0.77632385]
# Correlacion cruzada normalizada en traslacion y:  [-5.005]   [0.77546287]
# Correlacion cruzada normalizada en traslacion y:  [-4.55]   [0.7748482]
# La tercera traslacion es:  [-11.375]
# Correlacion cruzada normalizada en rotación:  1.17   [0.7723985]
# Correlacion cruzada normalizada en rotación:  1.1729999999999998   [0.77237827]
# Correlacion cruzada normalizada en rotación:  1.176   [0.7723674]
# Correlacion cruzada normalizada en rotación:  1.1789999999999998   [0.7723442]
# Correlacion cruzada normalizada en rotación:  1.182   [0.7723267]
# Correlacion cruzada normalizada en rotación:  1.1849999999999998   [0.7723084]
# Correlacion cruzada normalizada en rotación:  1.188   [0.77228713]
# Correlacion cruzada normalizada en rotación:  1.1909999999999998   [0.7722813]
# Correlacion cruzada normalizada en rotación:  1.194   [0.77225626]
# Correlacion cruzada normalizada en rotación:  1.1969999999999998   [0.77224606]
# Correlacion cruzada normalizada en rotación:  1.2   [0.7722252]
# Correlacion cruzada normalizada en rotación:  1.2029999999999998   [0.7722104]
# Correlacion cruzada normalizada en rotación:  1.206   [0.77218753]
# Correlacion cruzada normalizada en rotación:  1.2089999999999999   [0.7721641]
# Correlacion cruzada normalizada en rotación:  1.212   [0.77214926]
# Correlacion cruzada normalizada en rotación:  1.2149999999999999   [0.77212894]
# Correlacion cruzada normalizada en rotación:  1.218   [0.7721188]
# Correlacion cruzada normalizada en rotación:  1.2209999999999999   [0.772098]
# Correlacion cruzada normalizada en rotación:  1.224   [0.7720818]
# Correlacion cruzada normalizada en rotación:  1.2269999999999999   [0.7720631]
# Correlacion cruzada normalizada en rotación:  1.23   [0.77204585]
# La tercera rotación es:  [1.17]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc9cf7b8350>,
#  <matplotlib.image.AxesImage at 0x7fc9cf2d1050>,
#  Text(0.5, 1.0, 'Registro Completo'))

# %% [markdown]
# Resultados en BGR

# %%
# Mostrando el resultado final en BGR #

presion_BGR= cv2.imread("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/PresionPreProcesadaFinalIzq.JPG")
print(presion_BGR.shape)
(presion_B,presion_G,presion_R) = cv2.split(presion_BGR)

rows, cols, channels = presion_BGR.shape

M_escala = cv2.getRotationMatrix2D((cols/2,rows/2),0,s3)
M_traslacion_x = np.float32([[1,0,x3],[0,1,0]])
M_traslacion_y = np.float32([[1,0,0],[0,1,y3]])
M_rotacion = cv2.getRotationMatrix2D((cols/2,rows/2),r3,1)

presion_B = cv2.warpAffine(presion_B, M_escala, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_x, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_traslacion_y, (cols,rows))
presion_B = cv2.warpAffine(presion_B, M_rotacion, (cols,rows))

presion_G = cv2.warpAffine(presion_G, M_escala, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_x, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_traslacion_y, (cols,rows))
presion_G = cv2.warpAffine(presion_G, M_rotacion, (cols,rows))

presion_R = cv2.warpAffine(presion_R, M_escala, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_x, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_traslacion_y, (cols,rows))
presion_R = cv2.warpAffine(presion_R, M_rotacion, (cols,rows))

presion_BGR_registro = cv2.merge([presion_B,presion_G,presion_R])

imagen1_RGB = cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)
presion_RGB_registro = cv2.cvtColor(presion_BGR_registro, cv2.COLOR_BGR2RGB)

plt.figure(12)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')


#Mostrar la imagen fusionada
I_fusionada = cv2.addWeighted(imagen1,0.4,presion_BGR_registro,0.6,0)
cv2_imshow(I_fusionada)
# Out:
# (455, 455, 3)
# <PIL.Image.Image image mode=RGB size=455x455 at 0x7FC9CEF76C50>

# %% [markdown]
# Métricas de comparación

# %%
#Midiendo la información mutua final del registro
imagen1_RGB_gris = cv2.cvtColor(imagen1_RGB, cv2.COLOR_RGB2GRAY)
presion_RGB_registro_gris = cv2.cvtColor(presion_RGB_registro, cv2.COLOR_RGB2GRAY)

hist_2d, x_edges, y_edges = np.histogram2d(imagen1_RGB_gris.ravel(),presion_RGB_registro_gris.ravel(),bins=64)
    
# Calcular la información mutua entre las dos imágenes 
info_mutua_final = mutual_information(hist_2d)

#Midiendo la suma de diferencias al cuadrado
sqdiff = cv2.matchTemplate(imagen1_RGB_gris, presion_RGB_registro_gris, cv2.TM_SQDIFF)


plt.figure(13)
plt.subplot(121), plt.imshow(imagen1_RGB), plt.title('Original RGB')
plt.subplot(122),plt.imshow(presion_RGB_registro),plt.title('Registro Completo')

print("La información mutua es: ",info_mutua_final)
print("La sumatoria de diferencias al cuadrado es: ",sqdiff)
# Out:
# La información mutua es:  0.3797532908472897
# La sumatoria de diferencias al cuadrado es:  [[7.4472877e+08]]

# %% [markdown]
# Salida de imagen

# %%
Salida_registro = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_CCORR_NORMED.JPG",imagen2_sxyr3)
Salida_registro_BGR = cv2.imwrite("/content/drive/MyDrive/Trabajo de grado - Yeison Luna/Imagenes - Pruebas/Prueba 01-06-2021/Registro_Completo_BGR_CCOR_NORMED.JPG",presion_BGR_registro)
